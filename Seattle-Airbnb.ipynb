# %% [markdown]
# # Seattle AirBNB Data Analysis

# %% [markdown]
# We will be going through AirBNB Data for Seattle to draw some Valuable Insights through House Renting Data and further down will try to create model to predict best possible Rent Price for Good Revenue.
#
# So Let's Go -

# %% [markdown]
# ## Step 1 - Importing Libraries and Dataset (Gather)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
calender = pd.read_csv('calendar.csv')
calender.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
listings = pd.read_csv('listings.csv')
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                10.0
# 1  Queen Anne is a wonderful, truly functional vi...  ...                10.0
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                10.0
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1              strict                              t
# 2              strict                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
reviews = pd.read_csv('reviews.csv')
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %% [markdown]
# Let's Analyze datatypes of all Dataframes and see if any changes required

# %% [markdown]
# Calender Data

# %%
calender.dtypes
# Out:
# listing_id     int64
# date          object
# available     object
# price         object
# dtype: object

# %%
calender['price'] = calender['price'].str.replace(',', '')
calender['price'] = calender['price'].str.replace('$', '')
calender['price'] = calender['price'].astype(float)

# %%
calender = calender.astype({'date': 'datetime64'})

# %%
calender.dtypes
# Out:
# listing_id             int64
# date          datetime64[ns]
# available             object
# price                float64
# dtype: object

# %%
calender
# Out:
#          listing_id       date available  price
# 0            241032 2016-01-04         t   85.0
# 1            241032 2016-01-05         t   85.0
# 2            241032 2016-01-06         f    NaN
# 3            241032 2016-01-07         f    NaN
# 4            241032 2016-01-08         f    NaN
# ...             ...        ...       ...    ...
# 1393565    10208623 2016-12-29         f    NaN
# 1393566    10208623 2016-12-30         f    NaN
# 1393567    10208623 2016-12-31         f    NaN
# 1393568    10208623 2017-01-01         f    NaN
# 1393569    10208623 2017-01-02         f    NaN
#
# [1393570 rows x 4 columns]

# %% [markdown]
# Reviews Data

# %%
reviews.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
reviews = reviews.astype({'date': 'datetime64'})

# %%
reviews.dtypes
# Out:
# listing_id                int64
# id                        int64
# date             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comments                 object
# dtype: object

# %%
reviews
# Out:
#        listing_id        id       date  reviewer_id reviewer_name  \
# 0         7202016  38917982 2015-07-19     28943674        Bianca
# 1         7202016  39087409 2015-07-20     32440555         Frank
# 2         7202016  39820030 2015-07-26     37722850           Ian
# 3         7202016  40813543 2015-08-02     33671805        George
# 4         7202016  41986501 2015-08-10     34959538          Ming
# ...           ...       ...        ...          ...           ...
# 84844     3624990  50436321 2015-10-12     37419458          Ryan
# 84845     3624990  51024875 2015-10-17      6933252         Linda
# 84846     3624990  51511988 2015-10-20     19543701         Jaime
# 84847     3624990  52814482 2015-11-02     24445024        Jørgen
# 84848     9727246  56429621 2015-12-13     30860360     Stephanie
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# 1      Kelly has a great room in a very central locat...
# 2      Very spacious apartment, and in a great neighb...
# 3      Close to Seattle Center and all it has to offe...
# 4      Kelly was a great host and very accommodating ...
# ...                                                  ...
# 84844  The description and pictures of the apartment ...
# 84845  We had an excellent stay. It was clean and com...
# 84846  Gran ubicación, cerca de todo lo atractivo del...
# 84847  Very good apartement, clean and well sized. Si...
# 84848  Breanne was a great host. Check in was easy, s...
#
# [84849 rows x 6 columns]

# %% [markdown]
# Listings Data

# %%
listings.dtypes
# Out:
# id                                    int64
# listing_url                          object
# scrape_id                             int64
# last_scraped                         object
# name                                 object
#                                      ...
# cancellation_policy                  object
# require_guest_profile_picture        object
# require_guest_phone_verification     object
# calculated_host_listings_count        int64
# reviews_per_month                   float64
# Length: 92, dtype: object

# %%
listings.describe
# Out:
# <bound method NDFrame.describe of             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# 1      2016-01-04   Bright & Airy Queen Anne Apartment
# 2      2016-01-04  New Modern House-Amazing water view
# 3      2016-01-04                   Queen Anne Chateau
# 4      2016-01-04       Charming craftsman 3 bdm house
# ...           ...                                  ...
# 3813   2016-01-04   3BR Mountain View House in Seattle
# 3814   2016-01-04    Portage Bay View!-One Bedroom Apt
# 3815   2016-01-04    Private apartment view of Lake WA
# 3816   2016-01-04    Amazing View with Modern Comfort!
# 3817   2016-01-04            Large Lakefront Apartment
#
#                                                 summary  \
# 0                                                   NaN
# 1     Chemically sensitive? We've removed the irrita...
# 2     New modern house built in 2013.  Spectacular s...
# 3     A charming apartment that sits atop Queen Anne...
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...
# 3814  800 square foot 1 bedroom basement apartment w...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     Make your self at home in this charming one-be...
# 1     Beautiful, hypoallergenic apartment in an extr...
# 2     Our house is modern, light and fresh with a wa...
# 3                                                   NaN
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house bright, stylish, and wheelch...
# 3814  This space has a great view of Portage Bay wit...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                             description experiences_offered  \
# 0     Make your self at home in this charming one-be...                none
# 1     Chemically sensitive? We've removed the irrita...                none
# 2     New modern house built in 2013.  Spectacular s...                none
# 3     A charming apartment that sits atop Queen Anne...                none
# 4     Cozy family craftman house in beautiful neighb...                none
# ...                                                 ...                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...                none
# 3814  800 square foot 1 bedroom basement apartment w...                none
# 3815  Very comfortable lower unit. Quiet, charming m...                none
# 3816  Cozy studio condo in the heart on Madison Park...                none
# 3817  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview  ...  \
# 0                                                   NaN  ...
# 1     Queen Anne is a wonderful, truly functional vi...  ...
# 2     Upper Queen Anne is a charming neighborhood fu...  ...
# 3                                                   NaN  ...
# 4     We are in the beautiful neighborhood of Queen ...  ...
# ...                                                 ...  ...
# 3813  We're located near lots of family fun. Woodlan...  ...
# 3814  The neighborhood is a quiet oasis that is clos...  ...
# 3815                                                NaN  ...
# 3816  Madison Park offers a peaceful slow pace upsca...  ...
# 3817                                                NaN  ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 0                   10.0                f     NaN         WASHINGTON
# 1                   10.0                f     NaN         WASHINGTON
# 2                   10.0                f     NaN         WASHINGTON
# 3                    NaN                f     NaN         WASHINGTON
# 4                    9.0                f     NaN         WASHINGTON
# ...                  ...              ...     ...                ...
# 3813                 8.0                f     NaN         WASHINGTON
# 3814                10.0                f     NaN         WASHINGTON
# 3815                 NaN                f     NaN         WASHINGTON
# 3816                 NaN                f     NaN         WASHINGTON
# 3817                 NaN                f     NaN         WASHINGTON
#
#      instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                   f            moderate                              f
# 1                   f              strict                              t
# 2                   f              strict                              f
# 3                   f            flexible                              f
# 4                   f              strict                              f
# ...               ...                 ...                            ...
# 3813                f              strict                              f
# 3814                f            moderate                              f
# 3815                f            moderate                              f
# 3816                f            moderate                              f
# 3817                f            flexible                              f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 0                                   f                              2
# 1                                   t                              6
# 2                                   f                              2
# 3                                   f                              1
# 4                                   f                              1
# ...                               ...                            ...
# 3813                                f                              8
# 3814                                f                              1
# 3815                                f                              1
# 3816                                f                              1
# 3817                                f                              1
#
#      reviews_per_month
# 0                 4.07
# 1                 1.48
# 2                 1.15
# 3                  NaN
# 4                 0.89
# ...                ...
# 3813              0.30
# 3814              2.00
# 3815               NaN
# 3816               NaN
# 3817               NaN
#
# [3818 rows x 92 columns]>

# %% [markdown]
# Let us Look first at columns which have Constant Value or No Value (Empty) and Omit them

# %%
listings.columns[listings.nunique() == 1]
# Out:
# Index(['scrape_id', 'last_scraped', 'experiences_offered', 'market',
#        'country_code', 'country', 'has_availability', 'calendar_last_scraped',
#        'requires_license', 'jurisdiction_names'],
#       dtype='object')

# %%
listings[['scrape_id', 'last_scraped', 'experiences_offered', 'market',
       'country_code', 'country', 'has_availability', 'calendar_last_scraped',
       'requires_license', 'jurisdiction_names']]
# Out:
#            scrape_id last_scraped experiences_offered   market country_code  \
# 0     20160104002432   2016-01-04                none  Seattle           US
# 1     20160104002432   2016-01-04                none  Seattle           US
# 2     20160104002432   2016-01-04                none  Seattle           US
# 3     20160104002432   2016-01-04                none  Seattle           US
# 4     20160104002432   2016-01-04                none  Seattle           US
# ...              ...          ...                 ...      ...          ...
# 3813  20160104002432   2016-01-04                none  Seattle           US
# 3814  20160104002432   2016-01-04                none  Seattle           US
# 3815  20160104002432   2016-01-04                none  Seattle           US
# 3816  20160104002432   2016-01-04                none  Seattle           US
# 3817  20160104002432   2016-01-04                none  Seattle           US
#
#             country has_availability calendar_last_scraped requires_license  \
# 0     United States                t            2016-01-04                f
# 1     United States                t            2016-01-04                f
# 2     United States                t            2016-01-04                f
# 3     United States                t            2016-01-04                f
# 4     United States                t            2016-01-04                f
# ...             ...              ...                   ...              ...
# 3813  United States                t            2016-01-04                f
# 3814  United States                t            2016-01-04                f
# 3815  United States                t            2016-01-04                f
# 3816  United States                t            2016-01-04                f
# 3817  United States                t            2016-01-04                f
#
#      jurisdiction_names
# 0            WASHINGTON
# 1            WASHINGTON
# 2            WASHINGTON
# 3            WASHINGTON
# 4            WASHINGTON
# ...                 ...
# 3813         WASHINGTON
# 3814         WASHINGTON
# 3815         WASHINGTON
# 3816         WASHINGTON
# 3817         WASHINGTON
#
# [3818 rows x 10 columns]

# %% [markdown]
# We can see that these columns have constant values but at the same time some data is useful to basically have the idea of broad spectrum of this whole data. So we will drop these columns from listings and save all these columns in listings_const to keep record

# %%
listings_const = listings[['scrape_id', 'last_scraped', 'experiences_offered', 'market',
       'country_code', 'country', 'has_availability', 'calendar_last_scraped',
       'requires_license', 'jurisdiction_names']]

listings.drop(axis=1,labels=['scrape_id', 'last_scraped', 'experiences_offered', 'market',
       'country_code', 'country', 'has_availability', 'calendar_last_scraped',
       'requires_license', 'jurisdiction_names'],inplace=True)

# %%
listings.columns[listings.nunique() == 0]
# Out:
# Index(['license'], dtype='object')

# %% [markdown]
# license column of listings is actually blank as their is no value present in it so it is of no use in our analysis

# %%
listings_const['license'] = listings['license']

listings.drop(axis=1,labels='license',inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   name                              3818 non-null   object
#  3   summary                           3641 non-null   object
#  4   space                             3249 non-null   object
#  5   description                       3818 non-null   object
#  6   neighborhood_overview             2786 non-null   object
#  7   notes                             2212 non-null   object
#  8   transit                           2884 non-null   object
#  9   thumbnail_url                     3498 non-null   object
#  10  medium_url                        3498 non-null   object
#  11  picture_url                       3818 non-null   object
#  12  xl_picture_url                    3498 non-null   object
#  13  host_id                           3818 non-null   int64
#  14  host_url                          3818 non-null   object
#  15  host_name                         3816 non-null   object
#  16  host_since                        3816 non-null   object
#  17  host_location                     3810 non-null   object
#  18  host_about                        2959 non-null   object
#  19  host_response_time                3295 non-null   object
#  20  host_response_rate                3295 non-null   object
#  21  host_acceptance_rate              3045 non-null   object
#  22  host_is_superhost                 3816 non-null   object
#  23  host_thumbnail_url                3816 non-null   object
#  24  host_picture_url                  3816 non-null   object
#  25  host_neighbourhood                3518 non-null   object
#  26  host_listings_count               3816 non-null   float64
#  27  host_total_listings_count         3816 non-null   float64
#  28  host_verifications                3818 non-null   object
#  29  host_has_profile_pic              3816 non-null   object
#  30  host_identity_verified            3816 non-null   object
#  31  street                            3818 non-null   object
#  32  neighbourhood                     3402 non-null   object
#  33  neighbourhood_cleansed            3818 non-null   object
#  34  neighbourhood_group_cleansed      3818 non-null   object
#  35  city                              3818 non-null   object
#  36  state                             3818 non-null   object
#  37  zipcode                           3811 non-null   object
#  38  smart_location                    3818 non-null   object
#  39  latitude                          3818 non-null   float64
#  40  longitude                         3818 non-null   float64
#  41  is_location_exact                 3818 non-null   object
#  42  property_type                     3817 non-null   object
#  43  room_type                         3818 non-null   object
#  44  accommodates                      3818 non-null   int64
#  45  bathrooms                         3802 non-null   float64
#  46  bedrooms                          3812 non-null   float64
#  47  beds                              3817 non-null   float64
#  48  bed_type                          3818 non-null   object
#  49  amenities                         3818 non-null   object
#  50  square_feet                       97 non-null     float64
#  51  price                             3818 non-null   object
#  52  weekly_price                      2009 non-null   object
#  53  monthly_price                     1517 non-null   object
#  54  security_deposit                  1866 non-null   object
#  55  cleaning_fee                      2788 non-null   object
#  56  guests_included                   3818 non-null   int64
#  57  extra_people                      3818 non-null   object
#  58  minimum_nights                    3818 non-null   int64
#  59  maximum_nights                    3818 non-null   int64
#  60  calendar_updated                  3818 non-null   object
#  61  availability_30                   3818 non-null   int64
#  62  availability_60                   3818 non-null   int64
#  63  availability_90                   3818 non-null   int64
#  64  availability_365                  3818 non-null   int64
#  65  number_of_reviews                 3818 non-null   int64
#  66  first_review                      3191 non-null   object
#  67  last_review                       3191 non-null   object
#  68  review_scores_rating              3171 non-null   float64
#  69  review_scores_accuracy            3160 non-null   float64
#  70  review_scores_cleanliness         3165 non-null   float64
#  71  review_scores_checkin             3160 non-null   float64
#  72  review_scores_communication       3167 non-null   float64
#  73  review_scores_location            3163 non-null   float64
#  74  review_scores_value               3162 non-null   float64
#  75  instant_bookable                  3818 non-null   object
#  76  cancellation_policy               3818 non-null   object
#  77  require_guest_profile_picture     3818 non-null   object
#  78  require_guest_phone_verification  3818 non-null   object
#  79  calculated_host_listings_count    3818 non-null   int64
#  80  reviews_per_month                 3191 non-null   float64
# dtypes: float64(16), int64(12), object(53)
# memory usage: 2.4+ MB

# %% [markdown]
# Below is Essential Cleaning in some expected Numerical Columns to convert them from String to Float or Int

# %%
listings['price'] = listings['price'].str.replace(',', '')
listings['price'] = listings['price'].str.replace('$', '')
listings['price'] = listings['price'].astype(float)

listings['weekly_price'] = listings['weekly_price'].str.replace(',', '')
listings['weekly_price'] = listings['weekly_price'].str.replace('$', '')
listings['weekly_price'] = listings['weekly_price'].astype(float)

listings['monthly_price'] = listings['monthly_price'].str.replace(',', '')
listings['monthly_price'] = listings['monthly_price'].str.replace('$', '')
listings['monthly_price'] = listings['monthly_price'].astype(float)

listings['security_deposit'] = listings['security_deposit'].str.replace(',', '')
listings['security_deposit'] = listings['security_deposit'].str.replace('$', '')
listings['security_deposit'] = listings['security_deposit'].astype(float)

listings['cleaning_fee'] = listings['cleaning_fee'].str.replace(',', '')
listings['cleaning_fee'] = listings['cleaning_fee'].str.replace('$', '')
listings['cleaning_fee'] = listings['cleaning_fee'].astype(float)

listings['host_response_rate'] = listings['host_response_rate'].str.replace('%', '')
listings['host_response_rate'] = listings['host_response_rate'].astype(float)

listings['host_acceptance_rate'] = listings['host_acceptance_rate'].str.replace('%', '')
listings['host_acceptance_rate'] = listings['host_acceptance_rate'].astype(float)

listings['extra_people'] = listings['extra_people'].str.replace(',', '')
listings['extra_people'] = listings['extra_people'].str.replace('$', '')
listings['extra_people'] = listings['extra_people'].astype(float)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   name                              3818 non-null   object
#  3   summary                           3641 non-null   object
#  4   space                             3249 non-null   object
#  5   description                       3818 non-null   object
#  6   neighborhood_overview             2786 non-null   object
#  7   notes                             2212 non-null   object
#  8   transit                           2884 non-null   object
#  9   thumbnail_url                     3498 non-null   object
#  10  medium_url                        3498 non-null   object
#  11  picture_url                       3818 non-null   object
#  12  xl_picture_url                    3498 non-null   object
#  13  host_id                           3818 non-null   int64
#  14  host_url                          3818 non-null   object
#  15  host_name                         3816 non-null   object
#  16  host_since                        3816 non-null   object
#  17  host_location                     3810 non-null   object
#  18  host_about                        2959 non-null   object
#  19  host_response_time                3295 non-null   object
#  20  host_response_rate                3295 non-null   float64
#  21  host_acceptance_rate              3045 non-null   float64
#  22  host_is_superhost                 3816 non-null   object
#  23  host_thumbnail_url                3816 non-null   object
#  24  host_picture_url                  3816 non-null   object
#  25  host_neighbourhood                3518 non-null   object
#  26  host_listings_count               3816 non-null   float64
#  27  host_total_listings_count         3816 non-null   float64
#  28  host_verifications                3818 non-null   object
#  29  host_has_profile_pic              3816 non-null   object
#  30  host_identity_verified            3816 non-null   object
#  31  street                            3818 non-null   object
#  32  neighbourhood                     3402 non-null   object
#  33  neighbourhood_cleansed            3818 non-null   object
#  34  neighbourhood_group_cleansed      3818 non-null   object
#  35  city                              3818 non-null   object
#  36  state                             3818 non-null   object
#  37  zipcode                           3811 non-null   object
#  38  smart_location                    3818 non-null   object
#  39  latitude                          3818 non-null   float64
#  40  longitude                         3818 non-null   float64
#  41  is_location_exact                 3818 non-null   object
#  42  property_type                     3817 non-null   object
#  43  room_type                         3818 non-null   object
#  44  accommodates                      3818 non-null   int64
#  45  bathrooms                         3802 non-null   float64
#  46  bedrooms                          3812 non-null   float64
#  47  beds                              3817 non-null   float64
#  48  bed_type                          3818 non-null   object
#  49  amenities                         3818 non-null   object
#  50  square_feet                       97 non-null     float64
#  51  price                             3818 non-null   float64
#  52  weekly_price                      2009 non-null   float64
#  53  monthly_price                     1517 non-null   float64
#  54  security_deposit                  1866 non-null   float64
#  55  cleaning_fee                      2788 non-null   float64
#  56  guests_included                   3818 non-null   int64
#  57  extra_people                      3818 non-null   float64
#  58  minimum_nights                    3818 non-null   int64
#  59  maximum_nights                    3818 non-null   int64
#  60  calendar_updated                  3818 non-null   object
#  61  availability_30                   3818 non-null   int64
#  62  availability_60                   3818 non-null   int64
#  63  availability_90                   3818 non-null   int64
#  64  availability_365                  3818 non-null   int64
#  65  number_of_reviews                 3818 non-null   int64
#  66  first_review                      3191 non-null   object
#  67  last_review                       3191 non-null   object
#  68  review_scores_rating              3171 non-null   float64
#  69  review_scores_accuracy            3160 non-null   float64
#  70  review_scores_cleanliness         3165 non-null   float64
#  71  review_scores_checkin             3160 non-null   float64
#  72  review_scores_communication       3167 non-null   float64
#  73  review_scores_location            3163 non-null   float64
#  74  review_scores_value               3162 non-null   float64
#  75  instant_bookable                  3818 non-null   object
#  76  cancellation_policy               3818 non-null   object
#  77  require_guest_profile_picture     3818 non-null   object
#  78  require_guest_phone_verification  3818 non-null   object
#  79  calculated_host_listings_count    3818 non-null   int64
#  80  reviews_per_month                 3191 non-null   float64
# dtypes: float64(24), int64(12), object(45)
# memory usage: 2.4+ MB

# %%
listings['price']
# Out:
# 0        85.0
# 1       150.0
# 2       975.0
# 3       100.0
# 4       450.0
#         ...
# 3813    359.0
# 3814     79.0
# 3815     93.0
# 3816     99.0
# 3817     87.0
# Name: price, Length: 3818, dtype: float64

# %%
listings[['first_review','last_review']]
# Out:
#      first_review last_review
# 0      2011-11-01  2016-01-02
# 1      2013-08-19  2015-12-29
# 2      2014-07-30  2015-09-03
# 3             NaN         NaN
# 4      2012-07-10  2015-10-24
# ...           ...         ...
# 3813   2015-09-27  2015-09-27
# 3814   2015-12-18  2015-12-24
# 3815          NaN         NaN
# 3816          NaN         NaN
# 3817          NaN         NaN
#
# [3818 rows x 2 columns]

# %%
listings = listings.astype({'first_review': 'datetime64','last_review': 'datetime64','host_since': 'datetime64'})

# %%
listings.rename(columns={'id':'listing_id'}, inplace=True)

# %% [markdown]
# Now we combine Listings and Reviews before going on to draw some initial insights from Data
#
# listing_org is created just to have original listings saved as I wiil be performing join on listings itself and it is good to have backup if something is required for QA

# %%
listings_org = listings

# %%
listings = pd.merge(listings,reviews,on='listing_id')
listings['estimated_revenue'] = listings['price'] * listings['minimum_nights']

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84849 entries, 0 to 84848
# Data columns (total 87 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_id                        84849 non-null  int64
#  1   listing_url                       84849 non-null  object
#  2   name                              84849 non-null  object
#  3   summary                           75850 non-null  object
#  4   space                             81901 non-null  object
#  5   description                       84849 non-null  object
#  6   neighborhood_overview             66434 non-null  object
#  7   notes                             56690 non-null  object
#  8   transit                           70120 non-null  object
#  9   thumbnail_url                     79801 non-null  object
#  10  medium_url                        79801 non-null  object
#  11  picture_url                       84849 non-null  object
#  12  xl_picture_url                    79801 non-null  object
#  13  host_id                           84849 non-null  int64
#  14  host_url                          84849 non-null  object
#  15  host_name                         84849 non-null  object
#  16  host_since                        84849 non-null  datetime64[ns]
#  17  host_location                     84849 non-null  object
#  18  host_about                        78173 non-null  object
#  19  host_response_time                81210 non-null  object
#  20  host_response_rate                81210 non-null  float64
#  21  host_acceptance_rate              79409 non-null  float64
#  22  host_is_superhost                 84849 non-null  object
#  23  host_thumbnail_url                84849 non-null  object
#  24  host_picture_url                  84849 non-null  object
#  25  host_neighbourhood                81968 non-null  object
#  26  host_listings_count               84849 non-null  float64
#  27  host_total_listings_count         84849 non-null  float64
#  28  host_verifications                84849 non-null  object
#  29  host_has_profile_pic              84849 non-null  object
#  30  host_identity_verified            84849 non-null  object
#  31  street                            84849 non-null  object
#  32  neighbourhood                     80190 non-null  object
#  33  neighbourhood_cleansed            84849 non-null  object
#  34  neighbourhood_group_cleansed      84849 non-null  object
#  35  city                              84849 non-null  object
#  36  state                             84849 non-null  object
#  37  zipcode                           84637 non-null  object
#  38  smart_location                    84849 non-null  object
#  39  latitude                          84849 non-null  float64
#  40  longitude                         84849 non-null  float64
#  41  is_location_exact                 84849 non-null  object
#  42  property_type                     84849 non-null  object
#  43  room_type                         84849 non-null  object
#  44  accommodates                      84849 non-null  int64
#  45  bathrooms                         84240 non-null  float64
#  46  bedrooms                          84559 non-null  float64
#  47  beds                              84849 non-null  float64
#  48  bed_type                          84849 non-null  object
#  49  amenities                         84849 non-null  object
#  50  square_feet                       4252 non-null   float64
#  51  price                             84849 non-null  float64
#  52  weekly_price                      46362 non-null  float64
#  53  monthly_price                     36088 non-null  float64
#  54  security_deposit                  42116 non-null  float64
#  55  cleaning_fee                      61310 non-null  float64
#  56  guests_included                   84849 non-null  int64
#  57  extra_people                      84849 non-null  float64
#  58  minimum_nights                    84849 non-null  int64
#  59  maximum_nights                    84849 non-null  int64
#  60  calendar_updated                  84849 non-null  object
#  61  availability_30                   84849 non-null  int64
#  62  availability_60                   84849 non-null  int64
#  63  availability_90                   84849 non-null  int64
#  64  availability_365                  84849 non-null  int64
#  65  number_of_reviews                 84849 non-null  int64
#  66  first_review                      84849 non-null  datetime64[ns]
#  67  last_review                       84849 non-null  datetime64[ns]
#  68  review_scores_rating              84829 non-null  float64
#  69  review_scores_accuracy            84815 non-null  float64
#  70  review_scores_cleanliness         84822 non-null  float64
#  71  review_scores_checkin             84815 non-null  float64
#  72  review_scores_communication       84824 non-null  float64
#  73  review_scores_location            84818 non-null  float64
#  74  review_scores_value               84817 non-null  float64
#  75  instant_bookable                  84849 non-null  object
#  76  cancellation_policy               84849 non-null  object
#  77  require_guest_profile_picture     84849 non-null  object
#  78  require_guest_phone_verification  84849 non-null  object
#  79  calculated_host_listings_count    84849 non-null  int64
#  80  reviews_per_month                 84849 non-null  float64
#  81  id                                84849 non-null  int64
#  82  date                              84849 non-null  datetime64[ns]
#  83  reviewer_id                       84849 non-null  int64
#  84  reviewer_name                     84849 non-null  object
#  85  comments                          84831 non-null  object
#  86  estimated_revenue                 84849 non-null  float64
# dtypes: datetime64[ns](4), float64(25), int64(14), object(44)
# memory usage: 57.0+ MB

# %%
listings.columns[listings.nunique() == 1]
# Out:
# Index(['state'], dtype='object')

# %%
listings_reviews_const = listings['state']

listings.drop(axis=1,labels=['state'],inplace=True)

# %% [raw]
# listings have city and smart_location as two different column by name but they have all values same for every row so it is better to exclude one of any of the column to avoid any confusion and have good model predictions by avoiding collinearity

# %%
listings['city'].value_counts()
# Out:
# Seattle                  84667
# Ballard, Seattle            74
# West Seattle                40
# Seattle                     30
# 西雅图                         27
# Phinney Ridge Seattle       11
# Name: city, dtype: int64

# %%
listings['smart_location'].value_counts()
# Out:
# Seattle, WA                  84667
# Ballard, Seattle, WA            74
# West Seattle, WA                40
# Seattle , WA                    30
# 西雅图, WA                         27
# Phinney Ridge Seattle, WA       11
# Name: smart_location, dtype: int64

# %%
listings['city'].equals(listings['smart_location'].apply(lambda x:x.split(',')[0]))
# Out:
# False

# %%
listings['temp_smart_location'] = listings['smart_location'].apply(lambda x:x.split(',')[0])

# %%
listings[['city','temp_smart_location']]
# Out:
#           city temp_smart_location
# 0      Seattle             Seattle
# 1      Seattle             Seattle
# 2      Seattle             Seattle
# 3      Seattle             Seattle
# 4      Seattle             Seattle
# ...        ...                 ...
# 84844  Seattle             Seattle
# 84845  Seattle             Seattle
# 84846  Seattle             Seattle
# 84847  Seattle             Seattle
# 84848  Seattle             Seattle
#
# [84849 rows x 2 columns]

# %%
listings['city'].equals(listings['temp_smart_location'])
# Out:
# False

# %%
listings['temp_smart_location'].value_counts()
# Out:
# Seattle                  84667
# Ballard                     74
# West Seattle                40
# Seattle                     30
# 西雅图                         27
# Phinney Ridge Seattle       11
# Name: temp_smart_location, dtype: int64

# %%
listings['temp_smart_location'].replace(to_replace='Ballard',value='Ballard, Seattle',inplace=True)

# %%
listings['temp_smart_location'].value_counts()
# Out:
# Seattle                  84667
# Ballard, Seattle            74
# West Seattle                40
# Seattle                     30
# 西雅图                         27
# Phinney Ridge Seattle       11
# Name: temp_smart_location, dtype: int64

# %% [raw]
# Below cell on running return True which means that the manipulated smart_location (temp_smart_location) and city columns are exactly carrying same values so to avoid multicollinearity we drop one of the city or smart_location column and temp_smart_location is also dropped as it was introduced only for manipulation purpose

# %%
listings['city'].equals(listings['temp_smart_location'])
# Out:
# True

# %%
listings.drop(axis=1,labels='temp_smart_location',inplace=True)

# %%
listings_reviews_const['smart_location'] = listings['smart_location']

listings.drop(axis=1,labels=['smart_location'],inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84849 entries, 0 to 84848
# Data columns (total 85 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_id                        84849 non-null  int64
#  1   listing_url                       84849 non-null  object
#  2   name                              84849 non-null  object
#  3   summary                           75850 non-null  object
#  4   space                             81901 non-null  object
#  5   description                       84849 non-null  object
#  6   neighborhood_overview             66434 non-null  object
#  7   notes                             56690 non-null  object
#  8   transit                           70120 non-null  object
#  9   thumbnail_url                     79801 non-null  object
#  10  medium_url                        79801 non-null  object
#  11  picture_url                       84849 non-null  object
#  12  xl_picture_url                    79801 non-null  object
#  13  host_id                           84849 non-null  int64
#  14  host_url                          84849 non-null  object
#  15  host_name                         84849 non-null  object
#  16  host_since                        84849 non-null  datetime64[ns]
#  17  host_location                     84849 non-null  object
#  18  host_about                        78173 non-null  object
#  19  host_response_time                81210 non-null  object
#  20  host_response_rate                81210 non-null  float64
#  21  host_acceptance_rate              79409 non-null  float64
#  22  host_is_superhost                 84849 non-null  object
#  23  host_thumbnail_url                84849 non-null  object
#  24  host_picture_url                  84849 non-null  object
#  25  host_neighbourhood                81968 non-null  object
#  26  host_listings_count               84849 non-null  float64
#  27  host_total_listings_count         84849 non-null  float64
#  28  host_verifications                84849 non-null  object
#  29  host_has_profile_pic              84849 non-null  object
#  30  host_identity_verified            84849 non-null  object
#  31  street                            84849 non-null  object
#  32  neighbourhood                     80190 non-null  object
#  33  neighbourhood_cleansed            84849 non-null  object
#  34  neighbourhood_group_cleansed      84849 non-null  object
#  35  city                              84849 non-null  object
#  36  zipcode                           84637 non-null  object
#  37  latitude                          84849 non-null  float64
#  38  longitude                         84849 non-null  float64
#  39  is_location_exact                 84849 non-null  object
#  40  property_type                     84849 non-null  object
#  41  room_type                         84849 non-null  object
#  42  accommodates                      84849 non-null  int64
#  43  bathrooms                         84240 non-null  float64
#  44  bedrooms                          84559 non-null  float64
#  45  beds                              84849 non-null  float64
#  46  bed_type                          84849 non-null  object
#  47  amenities                         84849 non-null  object
#  48  square_feet                       4252 non-null   float64
#  49  price                             84849 non-null  float64
#  50  weekly_price                      46362 non-null  float64
#  51  monthly_price                     36088 non-null  float64
#  52  security_deposit                  42116 non-null  float64
#  53  cleaning_fee                      61310 non-null  float64
#  54  guests_included                   84849 non-null  int64
#  55  extra_people                      84849 non-null  float64
#  56  minimum_nights                    84849 non-null  int64
#  57  maximum_nights                    84849 non-null  int64
#  58  calendar_updated                  84849 non-null  object
#  59  availability_30                   84849 non-null  int64
#  60  availability_60                   84849 non-null  int64
#  61  availability_90                   84849 non-null  int64
#  62  availability_365                  84849 non-null  int64
#  63  number_of_reviews                 84849 non-null  int64
#  64  first_review                      84849 non-null  datetime64[ns]
#  65  last_review                       84849 non-null  datetime64[ns]
#  66  review_scores_rating              84829 non-null  float64
#  67  review_scores_accuracy            84815 non-null  float64
#  68  review_scores_cleanliness         84822 non-null  float64
#  69  review_scores_checkin             84815 non-null  float64
#  70  review_scores_communication       84824 non-null  float64
#  71  review_scores_location            84818 non-null  float64
#  72  review_scores_value               84817 non-null  float64
#  73  instant_bookable                  84849 non-null  object
#  74  cancellation_policy               84849 non-null  object
#  75  require_guest_profile_picture     84849 non-null  object
#  76  require_guest_phone_verification  84849 non-null  object
#  77  calculated_host_listings_count    84849 non-null  int64
#  78  reviews_per_month                 84849 non-null  float64
#  79  id                                84849 non-null  int64
#  80  date                              84849 non-null  datetime64[ns]
#  81  reviewer_id                       84849 non-null  int64
#  82  reviewer_name                     84849 non-null  object
#  83  comments                          84831 non-null  object
#  84  estimated_revenue                 84849 non-null  float64
# dtypes: datetime64[ns](4), float64(25), int64(14), object(42)
# memory usage: 58.2+ MB

# %% [markdown]
# ## Step 2 - Exploratory Data Analysis (Analyze, Visualize)

# %% [markdown]
# Now Let's move to draw some initial insights by Exploratory Data Analysis on Data and get answers of our questions

# %% [markdown]
# ### Major Questions -

# %% [markdown]
# (1) What is the Peak Season of Housing at Seattle in terms of Price?
#
# (2) What is the Peak Season of Housing at Seattle in terms of Revenue?
#
# (3) Is there any importance of Permission of Guests allowed by Host on Listings?
#
# (4) Is there any Importance of Verification for Future Hosts?
#
# (5) What is the general Nature of Seattle Hosts from Social Perspective?
#
# (6) Is Company really providing any Benefits toHosts identified as “SuperHost” in terms of Revenue?

# %% [markdown]
# #### Please Note - All other Visualiztions are part of Exploration of Data to search ofr Insight. So I haven't provided comments for each and every visualization

# %% [markdown]
# Calender Data

# %%
calender
# Out:
#          listing_id       date available  price
# 0            241032 2016-01-04         t   85.0
# 1            241032 2016-01-05         t   85.0
# 2            241032 2016-01-06         f    NaN
# 3            241032 2016-01-07         f    NaN
# 4            241032 2016-01-08         f    NaN
# ...             ...        ...       ...    ...
# 1393565    10208623 2016-12-29         f    NaN
# 1393566    10208623 2016-12-30         f    NaN
# 1393567    10208623 2016-12-31         f    NaN
# 1393568    10208623 2017-01-01         f    NaN
# 1393569    10208623 2017-01-02         f    NaN
#
# [1393570 rows x 4 columns]

# %%
series = calender[calender['available'] == 't']['date'].value_counts()

# %%
series
# Out:
# 2017-01-01    2922
# 2016-12-31    2859
# 2016-12-30    2840
# 2016-12-29    2835
# 2016-12-28    2833
#               ...
# 2016-01-09    1856
# 2016-01-06    1826
# 2016-01-08    1782
# 2016-01-07    1776
# 2016-01-04    1735
# Name: date, Length: 365, dtype: int64

# %%
#This Visualization is just for Test (No Insight)
series.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
#This Visualization is just for Test (No Insight)
import matplotlib.dates as mdates
plt.figure(figsize=(12,6))
myFmt = mdates.DateFormatter('%y-%m') # here you can format your datetick labels as desired
plt.plot_date(series.index,series.values)
plt.gca().xaxis.set_major_formatter(myFmt)
plt.xticks()
# Out:
# (array([16801., 16861., 16922., 16983., 17045., 17106., 17167.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
calender['year'] = calender['date'].apply(lambda x: x.year)
calender['month'] = calender['date'].apply(lambda x: x.month)
calender['day'] = calender['date'].apply(lambda x: x.day)

# %%
calender
# Out:
#          listing_id       date available  price  year  month  day
# 0            241032 2016-01-04         t   85.0  2016      1    4
# 1            241032 2016-01-05         t   85.0  2016      1    5
# 2            241032 2016-01-06         f    NaN  2016      1    6
# 3            241032 2016-01-07         f    NaN  2016      1    7
# 4            241032 2016-01-08         f    NaN  2016      1    8
# ...             ...        ...       ...    ...   ...    ...  ...
# 1393565    10208623 2016-12-29         f    NaN  2016     12   29
# 1393566    10208623 2016-12-30         f    NaN  2016     12   30
# 1393567    10208623 2016-12-31         f    NaN  2016     12   31
# 1393568    10208623 2017-01-01         f    NaN  2017      1    1
# 1393569    10208623 2017-01-02         f    NaN  2017      1    2
#
# [1393570 rows x 7 columns]

# %% [markdown]
# ### What is the Peak Season of Housing at Seattle in terms of Price?

# %% [markdown]
# From below Figure it can be clearly observed that Highest Price Season for Airbnb at Seattle is from June-August which are generally due to Vacations and litte increase in December due to Christmas and New Year leading to Inflation of Hosing Price whereas there is no trend (Noise) in Pricing based on Day of Month

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(24,6))
sns.lineplot(x='day',y='price',data=calender[calender['available'] == 't'],marker='o',markersize=10,ax=ax[0])
sns.lineplot(x='month',y='price',data=calender[calender['available'] == 't'],marker='o',markersize=10,ax=ax[1])
plt.xticks(np.arange(1,13,1))
# Out:
# ([<matplotlib.axis.XTick at 0x23019bcc508>,
#   <matplotlib.axis.XTick at 0x23019bce7c8>,
#   <matplotlib.axis.XTick at 0x2301acf9508>,
#   <matplotlib.axis.XTick at 0x2301ab6a448>,
#   <matplotlib.axis.XTick at 0x2301ab6ab48>,
#   <matplotlib.axis.XTick at 0x2301ab6d408>,
#   <matplotlib.axis.XTick at 0x2301ab6dc48>,
#   <matplotlib.axis.XTick at 0x2301ab714c8>,
#   <matplotlib.axis.XTick at 0x23019bcccc8>,
#   <matplotlib.axis.XTick at 0x2301ab7f948>,
#   <matplotlib.axis.XTick at 0x2301ab83148>,
#   <matplotlib.axis.XTick at 0x2301ab83c88>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(24,6))
sns.countplot(x='day',data=calender[calender['available'] == 't'],ax=ax[0])
sns.countplot(x='month',data=calender[calender['available'] == 't'],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %% [markdown]
# Listings Data

# %%
listings
# Out:
#        listing_id                           listing_url  \
# 0          241032   https://www.airbnb.com/rooms/241032
# 1          241032   https://www.airbnb.com/rooms/241032
# 2          241032   https://www.airbnb.com/rooms/241032
# 3          241032   https://www.airbnb.com/rooms/241032
# 4          241032   https://www.airbnb.com/rooms/241032
# ...           ...                                   ...
# 84844     3383329  https://www.airbnb.com/rooms/3383329
# 84845     3383329  https://www.airbnb.com/rooms/3383329
# 84846     8101950  https://www.airbnb.com/rooms/8101950
# 84847     8902327  https://www.airbnb.com/rooms/8902327
# 84848     8902327  https://www.airbnb.com/rooms/8902327
#
#                                       name  \
# 0             Stylish Queen Anne Apartment
# 1             Stylish Queen Anne Apartment
# 2             Stylish Queen Anne Apartment
# 3             Stylish Queen Anne Apartment
# 4             Stylish Queen Anne Apartment
# ...                                    ...
# 84844  OF THE TREE & CLOUDS. KID FRIENDLY!
# 84845  OF THE TREE & CLOUDS. KID FRIENDLY!
# 84846   3BR Mountain View House in Seattle
# 84847    Portage Bay View!-One Bedroom Apt
# 84848    Portage Bay View!-One Bedroom Apt
#
#                                                  summary  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 84844  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 84845  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 84846  Our 3BR/2BA house boasts incredible views of t...
# 84847  800 square foot 1 bedroom basement apartment w...
# 84848  800 square foot 1 bedroom basement apartment w...
#
#                                                    space  \
# 0      Make your self at home in this charming one-be...
# 1      Make your self at home in this charming one-be...
# 2      Make your self at home in this charming one-be...
# 3      Make your self at home in this charming one-be...
# 4      Make your self at home in this charming one-be...
# ...                                                  ...
# 84844  The 1-bedroom, ground-floor Roots apartment is...
# 84845  The 1-bedroom, ground-floor Roots apartment is...
# 84846  Our 3BR/2BA house bright, stylish, and wheelch...
# 84847  This space has a great view of Portage Bay wit...
# 84848  This space has a great view of Portage Bay wit...
#
#                                              description  \
# 0      Make your self at home in this charming one-be...
# 1      Make your self at home in this charming one-be...
# 2      Make your self at home in this charming one-be...
# 3      Make your self at home in this charming one-be...
# 4      Make your self at home in this charming one-be...
# ...                                                  ...
# 84844  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 84845  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 84846  Our 3BR/2BA house boasts incredible views of t...
# 84847  800 square foot 1 bedroom basement apartment w...
# 84848  800 square foot 1 bedroom basement apartment w...
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 84844  It's taken me a while to figure out why Fremon...
# 84845  It's taken me a while to figure out why Fremon...
# 84846  We're located near lots of family fun. Woodlan...
# 84847  The neighborhood is a quiet oasis that is clos...
# 84848  The neighborhood is a quiet oasis that is clos...
#
#                                                    notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 84844  There is NO television. We do have good WI-FI....
# 84845  There is NO television. We do have good WI-FI....
# 84846                                                NaN
# 84847  This is a basement apartment in a newer reside...
# 84848  This is a basement apartment in a newer reside...
#
#                                                  transit  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 84844  The apartment is easily accessed from I-5 Nort...
# 84845  The apartment is easily accessed from I-5 Nort...
# 84846                                                NaN
# 84847  Uber and Car2go are good options in Seattle. T...
# 84848  Uber and Car2go are good options in Seattle. T...
#
#                                            thumbnail_url  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 84844  https://a0.muscache.com/ac/pictures/108686685/...  ...
# 84845  https://a0.muscache.com/ac/pictures/108686685/...  ...
# 84846  https://a2.muscache.com/ac/pictures/103217071/...  ...
# 84847  https://a2.muscache.com/ac/pictures/626d4b1f-6...  ...
# 84848  https://a2.muscache.com/ac/pictures/626d4b1f-6...  ...
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 84844                             t                                t
# 84845                             t                                t
# 84846                             f                                f
# 84847                             f                                f
# 84848                             f                                f
#
#       calculated_host_listings_count  reviews_per_month        id       date  \
# 0                                  2               4.07    682061 2011-11-01
# 1                                  2               4.07    691712 2011-11-04
# 2                                  2               4.07    702999 2011-11-08
# 3                                  2               4.07    717262 2011-11-14
# 4                                  2               4.07    730226 2011-11-19
# ...                              ...                ...       ...        ...
# 84844                              3               4.01  55357027 2015-12-01
# 84845                              3               4.01  57757540 2015-12-29
# 84846                              8               0.30  48634004 2015-09-27
# 84847                              1               2.00  56818248 2015-12-18
# 84848                              1               2.00  57333693 2015-12-24
#
#       reviewer_id reviewer_name  \
# 0          479824           Bro
# 1          357699         Megan
# 2         1285567       Marylee
# 3          647857        Graham
# 4         1389821        Franka
# ...           ...           ...
# 84844    19459912         David
# 84845      645719         Betsi
# 84846    43900518      Jonathan
# 84847     1495780         James
# 84848    18708107       Jessica
#
#                                                 comments estimated_revenue
# 0      Excellent all the way around. \r\n\r\nMaija wa...              85.0
# 1      Maija's apartment was a wonderful place to sta...              85.0
# 2      one of the most pleasant stays i've had in my ...              85.0
# 3      Maija's suite is beautiful, cozy and convenien...              85.0
# 4      Our stay was short and pleasant. With its own ...              85.0
# ...                                                  ...               ...
# 84844  Had a great stay at Jacqueline's place! Plenty...             285.0
# 84845  Jacqueline was a fantastic host.  She was alwa...             285.0
# 84846  There was a bottle of wine and some chocolate ...            1077.0
# 84847  We had a great experience in a fantastic space...             158.0
# 84848  It is nicer than hotels, totally worth it. The...             158.0
#
# [84849 rows x 85 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84849 entries, 0 to 84848
# Data columns (total 85 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_id                        84849 non-null  int64
#  1   listing_url                       84849 non-null  object
#  2   name                              84849 non-null  object
#  3   summary                           75850 non-null  object
#  4   space                             81901 non-null  object
#  5   description                       84849 non-null  object
#  6   neighborhood_overview             66434 non-null  object
#  7   notes                             56690 non-null  object
#  8   transit                           70120 non-null  object
#  9   thumbnail_url                     79801 non-null  object
#  10  medium_url                        79801 non-null  object
#  11  picture_url                       84849 non-null  object
#  12  xl_picture_url                    79801 non-null  object
#  13  host_id                           84849 non-null  int64
#  14  host_url                          84849 non-null  object
#  15  host_name                         84849 non-null  object
#  16  host_since                        84849 non-null  datetime64[ns]
#  17  host_location                     84849 non-null  object
#  18  host_about                        78173 non-null  object
#  19  host_response_time                81210 non-null  object
#  20  host_response_rate                81210 non-null  float64
#  21  host_acceptance_rate              79409 non-null  float64
#  22  host_is_superhost                 84849 non-null  object
#  23  host_thumbnail_url                84849 non-null  object
#  24  host_picture_url                  84849 non-null  object
#  25  host_neighbourhood                81968 non-null  object
#  26  host_listings_count               84849 non-null  float64
#  27  host_total_listings_count         84849 non-null  float64
#  28  host_verifications                84849 non-null  object
#  29  host_has_profile_pic              84849 non-null  object
#  30  host_identity_verified            84849 non-null  object
#  31  street                            84849 non-null  object
#  32  neighbourhood                     80190 non-null  object
#  33  neighbourhood_cleansed            84849 non-null  object
#  34  neighbourhood_group_cleansed      84849 non-null  object
#  35  city                              84849 non-null  object
#  36  zipcode                           84637 non-null  object
#  37  latitude                          84849 non-null  float64
#  38  longitude                         84849 non-null  float64
#  39  is_location_exact                 84849 non-null  object
#  40  property_type                     84849 non-null  object
#  41  room_type                         84849 non-null  object
#  42  accommodates                      84849 non-null  int64
#  43  bathrooms                         84240 non-null  float64
#  44  bedrooms                          84559 non-null  float64
#  45  beds                              84849 non-null  float64
#  46  bed_type                          84849 non-null  object
#  47  amenities                         84849 non-null  object
#  48  square_feet                       4252 non-null   float64
#  49  price                             84849 non-null  float64
#  50  weekly_price                      46362 non-null  float64
#  51  monthly_price                     36088 non-null  float64
#  52  security_deposit                  42116 non-null  float64
#  53  cleaning_fee                      61310 non-null  float64
#  54  guests_included                   84849 non-null  int64
#  55  extra_people                      84849 non-null  float64
#  56  minimum_nights                    84849 non-null  int64
#  57  maximum_nights                    84849 non-null  int64
#  58  calendar_updated                  84849 non-null  object
#  59  availability_30                   84849 non-null  int64
#  60  availability_60                   84849 non-null  int64
#  61  availability_90                   84849 non-null  int64
#  62  availability_365                  84849 non-null  int64
#  63  number_of_reviews                 84849 non-null  int64
#  64  first_review                      84849 non-null  datetime64[ns]
#  65  last_review                       84849 non-null  datetime64[ns]
#  66  review_scores_rating              84829 non-null  float64
#  67  review_scores_accuracy            84815 non-null  float64
#  68  review_scores_cleanliness         84822 non-null  float64
#  69  review_scores_checkin             84815 non-null  float64
#  70  review_scores_communication       84824 non-null  float64
#  71  review_scores_location            84818 non-null  float64
#  72  review_scores_value               84817 non-null  float64
#  73  instant_bookable                  84849 non-null  object
#  74  cancellation_policy               84849 non-null  object
#  75  require_guest_profile_picture     84849 non-null  object
#  76  require_guest_phone_verification  84849 non-null  object
#  77  calculated_host_listings_count    84849 non-null  int64
#  78  reviews_per_month                 84849 non-null  float64
#  79  id                                84849 non-null  int64
#  80  date                              84849 non-null  datetime64[ns]
#  81  reviewer_id                       84849 non-null  int64
#  82  reviewer_name                     84849 non-null  object
#  83  comments                          84831 non-null  object
#  84  estimated_revenue                 84849 non-null  float64
# dtypes: datetime64[ns](4), float64(25), int64(14), object(42)
# memory usage: 58.2+ MB

# %%
listings[['price','review_scores_rating','review_scores_accuracy','review_scores_cleanliness',
          'review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']]
# Out:
#        price  review_scores_rating  review_scores_accuracy  \
# 0       85.0                  95.0                    10.0
# 1       85.0                  95.0                    10.0
# 2       85.0                  95.0                    10.0
# 3       85.0                  95.0                    10.0
# 4       85.0                  95.0                    10.0
# ...      ...                   ...                     ...
# 84844   95.0                  96.0                    10.0
# 84845   95.0                  96.0                    10.0
# 84846  359.0                  80.0                     8.0
# 84847   79.0                 100.0                    10.0
# 84848   79.0                 100.0                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           10.0                   10.0
# 1                           10.0                   10.0
# 2                           10.0                   10.0
# 3                           10.0                   10.0
# 4                           10.0                   10.0
# ...                          ...                    ...
# 84844                       10.0                   10.0
# 84845                       10.0                   10.0
# 84846                       10.0                    4.0
# 84847                       10.0                   10.0
# 84848                       10.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                     9.0
# 1                             10.0                     9.0
# 2                             10.0                     9.0
# 3                             10.0                     9.0
# 4                             10.0                     9.0
# ...                            ...                     ...
# 84844                         10.0                     9.0
# 84845                         10.0                     9.0
# 84846                          8.0                    10.0
# 84847                         10.0                    10.0
# 84848                         10.0                    10.0
#
#        review_scores_value
# 0                     10.0
# 1                     10.0
# 2                     10.0
# 3                     10.0
# 4                     10.0
# ...                    ...
# 84844                 10.0
# 84845                 10.0
# 84846                  8.0
# 84847                 10.0
# 84848                 10.0
#
# [84849 rows x 8 columns]

# %%
listings['host_location'].value_counts()
# Out:
# Seattle, Washington, United States       78199
# US                                        1681
# Kent, Washington, United States            509
# Seattle                                    503
# Spokane, Washington, United States         412
#                                          ...
# Ault, Colorado, United States                1
# Massachusetts, United States                 1
# Kenilworth, Illinois, United States          1
# Gig Harbor, Washington, United States        1
# Burien, Washington, United States            1
# Name: host_location, Length: 101, dtype: int64

# %%
len(listings['beds'].value_counts())
# Out:
# 11

# %%
len(listings['amenities'].value_counts())
# Out:
# 2750

# %%
for col in listings.columns:
    if len(listings[col].value_counts()) < 20:
        print(col)
# Out:
# host_response_time
# host_acceptance_rate
# host_is_superhost
# host_has_profile_pic
# host_identity_verified
# neighbourhood_group_cleansed
# city
# is_location_exact
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# bed_type
# guests_included
# minimum_nights
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# instant_bookable
# cancellation_policy
# require_guest_profile_picture
# require_guest_phone_verification
# calculated_host_listings_count

# %%
listings['guests_included'].value_counts()
# Out:
# 1     40284
# 2     32967
# 4      4722
# 0      2379
# 3      2162
# 6       969
# 8       584
# 7       391
# 5       311
# 10       41
# 13       21
# 9        14
# 12        4
# Name: guests_included, dtype: int64

# %% [markdown]
# ### Is there any importance of Permission of Guests allowed by Host on Listings?

# %% [markdown]
# From figures below, it is very clear that most of the Host allows 1-2 Guests with Customers and pricing also look in accordance with Frequency of Guetsts but for future Hosts if they can accommodate 5-6 Guests than it would be very great because of less competition and Good Revenue in return.

# %%
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(10,7))
sns.countplot(x='guests_included',data=listings,ax=ax[0])
sns.barplot(x='guests_included',y='price',data=listings,ax=ax[1])
plt.tight_layout()

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='guests_included',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='guests_included', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=1,ncols=4,figsize=(24,5))

sns.countplot(x='host_response_time',data=listings,ax=ax[0])
sns.barplot(x='host_response_time',y='price',data=listings,ax=ax[1])
sns.barplot(x='host_response_time',y='weekly_price',data=listings,ax=ax[2])
sns.barplot(x='host_response_time',y='monthly_price',data=listings,ax=ax[3])
plt.tight_layout()

# %%
sns.barplot(x='host_response_time',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='host_response_time', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
plt.figure(figsize=(16,12))
plt.subplot(411)
sns.countplot(x='property_type',data=listings)
plt.subplot(412)
sns.barplot(x='property_type',y='price',data=listings)
plt.subplot(413)
sns.barplot(x='property_type',y='weekly_price',data=listings)
plt.subplot(414)
sns.barplot(x='property_type',y='monthly_price',data=listings)

plt.tight_layout()

# %%
plt.figure(figsize=(16,5))
sns.barplot(x='property_type',y='estimated_revenue',data=listings)
plt.tight_layout()

# %%
#This Visualization is just for Exploration (No Insight)
sns.lineplot(x='review_scores_cleanliness',y='cleaning_fee',data=listings)
# Out:
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# <AxesSubplot:xlabel='review_scores_cleanliness', ylabel='cleaning_fee'>

# %%
listings['review_scores_cleanliness'].value_counts()
# Out:
# 10.0    57983
# 9.0     22520
# 8.0      3648
# 7.0       524
# 6.0       111
# 5.0        25
# 4.0         9
# 3.0         2
# Name: review_scores_cleanliness, dtype: int64

# %% [markdown]
# ###  Is there any Importance of Verification for Future Hosts?

# %% [markdown]
# It is interesting that most Renters get their Identity Verified to satisfy customer's security concerns but in Seattle it looks like Estimated Revenue of non verified hosts are more than verifed ones which is interesting insight showing that being Verified Host is not adding any value in terms of Earnings

# %%
fig, ax =plt.subplots(1,3,figsize=(16,4))

sns.countplot(x='host_identity_verified',data=listings,ax=ax[0])
sns.barplot(x='host_identity_verified',y='price',data=listings,ax=ax[1])
sns.barplot(x='host_identity_verified',y='estimated_revenue',data=listings,ax=ax[2])
# Out:
# <AxesSubplot:xlabel='host_identity_verified', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
plt.figure(figsize=(25,8))

sns.barplot(x='property_type',y='monthly_price',data=listings,hue='host_identity_verified')
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='monthly_price'>

# %%
#This Visualization is just for Exploration (No Insight)
plt.figure(figsize=(25,8))

sns.barplot(x='property_type',y='monthly_price',data=listings,hue='room_type')
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='monthly_price'>

# %% [markdown]
# ### What is the general Nature of Seattle Hosts from Social Perspective?

# %% [markdown]
# Here is unique thing to note not from Business Perspective but from Social Perspective that in Today's World where lots people migrate for jobs actually try to get single rooms or shared rooms rather than Whole House due to limited Funds but in Seattle nmost of the hosts offers Entire Home maybe targeting families but not very hosts are targetting singles or students who can't afford whole house which shows that Most hosts are Business MEant rather than Social Support

# %%
fig, ax =plt.subplots(1,3,figsize=(16,4))
sns.countplot(x='room_type',data=listings,ax=ax[0])
sns.barplot(x='room_type',y='price',data=listings,ax=ax[1])
sns.barplot(x='room_type',y='estimated_revenue',data=listings,ax=ax[2])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
sns.barplot(x='accommodates',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='accommodates', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
sns.barplot(x='bed_type',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='bed_type', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
sns.barplot(x='beds',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='beds', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
sns.barplot(x='bedrooms',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='estimated_revenue'>

# %%
#This Visualization is just for Exploration (No Insight)
sns.barplot(x='bathrooms',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='estimated_revenue'>

# %%
listings['room_type'].value_counts()
# Out:
# Entire home/apt    52465
# Private room       30870
# Shared room         1514
# Name: room_type, dtype: int64

# %%
listings['accommodates'].value_counts()
# Out:
# 2     42821
# 4     16041
# 3     10170
# 6      5580
# 1      3542
# 5      3221
# 8      1501
# 7       956
# 10      520
# 12      229
# 9        98
# 14       83
# 16       48
# 11       20
# 15       19
# Name: accommodates, dtype: int64

# %%
listings['bed_type'].value_counts()
# Out:
# Real Bed         81625
# Futon             1714
# Pull-out Sofa     1064
# Airbed             383
# Couch               63
# Name: bed_type, dtype: int64

# %%
listings['beds'].value_counts()
# Out:
# 1.0     54886
# 2.0     18522
# 3.0      7785
# 4.0      2421
# 5.0       576
# 6.0       264
# 7.0       209
# 9.0       103
# 8.0        56
# 15.0       18
# 10.0        9
# Name: beds, dtype: int64

# %%
listings['bedrooms'].value_counts()
# Out:
# 1.0    61399
# 2.0    10593
# 0.0     8113
# 3.0     3593
# 4.0      569
# 5.0      205
# 6.0       82
# 7.0        5
# Name: bedrooms, dtype: int64

# %%
listings['bathrooms'].value_counts()
# Out:
# 1.0    69850
# 1.5     5678
# 2.0     4905
# 2.5     1497
# 3.0     1179
# 3.5      570
# 0.5      366
# 4.5       58
# 4.0       56
# 0.0       46
# 5.0       27
# 8.0        8
# Name: bathrooms, dtype: int64

# %%
listings['host_has_profile_pic'].value_counts()
# Out:
# t    84813
# f       36
# Name: host_has_profile_pic, dtype: int64

# %% [markdown]
# ### Is Company really providing any Benefits toHosts identified as “SuperHost” in terms of Revenue?

# %% [markdown]
# As we saw in case of host who are verified or not, here also same situation is present with hosts those are superhost or not. Here again although there are very few host that have tag of superhost which is natural as it is difficult to reach upto that level and requirements but those hosts who are not superhost they have almost equivalent pricing with superhost and if that is the case than customer will choose Host with Superhost Tag as Normal Host have very high Price.

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.countplot(x='host_is_superhost',data=listings,ax=ax[0])
sns.barplot(x='host_is_superhost',y='price',data=listings,ax=ax[1])
plt.tight_layout()

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.countplot(x='host_has_profile_pic',data=listings,ax=ax[0])
sns.barplot(x='host_has_profile_pic',y='price',data=listings,ax=ax[1])
plt.tight_layout()

# %% [raw]
# This shows that most of the renters are verified on AirBNB Seattle Region but if we look at the pricing than there is no significant difference from those hosts who are not verified because people look for safety that host must be verified and if not than they could offer atleast low price as compared to Verified Hosts in order to get Crowd but here it is not the case

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.countplot(x='host_identity_verified',data=listings,ax=ax[0])
sns.barplot(x='host_identity_verified',y='price',data=listings,ax=ax[1])
plt.tight_layout()

# %% [raw]
# Below Graph-
#
# It is interesting that Most Renters are giving Entire Home/Apartment on Rent as compared to Private Room or Shared Room which
# is shocking thing to note as in today's world there are lot's of professionals and students who have less funds for accomodation but this shows like no body is thinking by business perspective to have private or shared room for this Group of people.

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
sns.countplot(x='room_type',data=listings,ax=ax[0])
sns.barplot(x='room_type',y='price',data=listings,ax=ax[1])
plt.tight_layout()

# %%
listings['neighbourhood_group_cleansed'].value_counts()
# Out:
# Other neighborhoods    17210
# Downtown               12606
# Capitol Hill           12412
# Central Area            8442
# Ballard                 7118
# Queen Anne              6613
# Rainier Valley          4085
# West Seattle            3407
# Beacon Hill             3355
# Delridge                2197
# Cascade                 1420
# Northgate               1389
# University District     1316
# Seward Park             1195
# Lake City               1028
# Magnolia                 933
# Interbay                 123
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
listings['minimum_nights'].value_counts()
# Out:
# 2       37212
# 1       35197
# 3        9917
# 4        1054
# 5         428
# 14        283
# 7         240
# 20        162
# 6         156
# 31        100
# 30         45
# 10         35
# 1000        8
# 29          4
# 13          3
# 12          3
# 21          1
# 26          1
# Name: minimum_nights, dtype: int64

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(24,10))
sns.countplot(x='neighbourhood_group_cleansed',data=listings,ax=ax[0])
sns.barplot(x='neighbourhood_group_cleansed',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %%
listings['estimated_revenue']
# Out:
# 0          85.0
# 1          85.0
# 2          85.0
# 3          85.0
# 4          85.0
#           ...
# 84844     285.0
# 84845     285.0
# 84846    1077.0
# 84847     158.0
# 84848     158.0
# Name: estimated_revenue, Length: 84849, dtype: float64

# %%
#This Visualization is just for Exploration (No Insight)
sns.lineplot(x='date',y='estimated_revenue',data=listings)
# Out:
# <AxesSubplot:xlabel='date', ylabel='estimated_revenue'>

# %%
listings['year'] = listings['date'].apply(lambda x: x.year)
listings['month'] = listings['date'].apply(lambda x: x.month)
listings['day'] = listings['date'].apply(lambda x: x.day)

# %%
listings['host_since_year'] = listings['host_since'].apply(lambda x: x.year)
listings['host_since_month'] = listings['host_since'].apply(lambda x: x.month)
listings['host_since_day'] = listings['host_since'].apply(lambda x: x.day)

# %%
listings['first_review_year'] = listings['first_review'].apply(lambda x: x.year)
listings['first_review_month'] = listings['first_review'].apply(lambda x: x.month)
listings['first_review_day'] = listings['first_review'].apply(lambda x: x.day)

# %%
listings['last_review_year'] = listings['last_review'].apply(lambda x: x.year)
listings['last_review_month'] = listings['last_review'].apply(lambda x: x.month)
listings['last_review_day'] = listings['last_review'].apply(lambda x: x.day)

# %%
listings['month']
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 84844    12
# 84845    12
# 84846     9
# 84847    12
# 84848    12
# Name: month, Length: 84849, dtype: int64

# %% [markdown]
# ### What is the Peak Season of Housing at Seattle in terms of Revenue?

# %% [markdown]
# In Contrast to Peak Season or Inflation Sason in terms of pricing, Peak Revenue Months are quite different because February and May are the Months which are providing Great Revenue as compared to Holiday Seasons when although Price is High but may be due to Competition Earnings are quite Low.

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='month',y='estimated_revenue',data=listings,marker='o',markersize=10)
plt.xticks(np.arange(1,13,1))
# Out:
# ([<matplotlib.axis.XTick at 0x2301e6d5dc8>,
#   <matplotlib.axis.XTick at 0x2301e73ef48>,
#   <matplotlib.axis.XTick at 0x2301e766f88>,
#   <matplotlib.axis.XTick at 0x2301e6edd48>,
#   <matplotlib.axis.XTick at 0x2301e6edfc8>,
#   <matplotlib.axis.XTick at 0x2301e6f0c48>,
#   <matplotlib.axis.XTick at 0x2301e6f0f88>,
#   <matplotlib.axis.XTick at 0x2301e736c08>,
#   <matplotlib.axis.XTick at 0x2301e750348>,
#   <matplotlib.axis.XTick at 0x2301e6b4d88>,
#   <matplotlib.axis.XTick at 0x2301e6e3c88>,
#   <matplotlib.axis.XTick at 0x2301e6e34c8>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(12,6))

sns.lineplot(x='year',y='estimated_revenue',data=listings,marker='o',markersize=10)
# Out:
# <AxesSubplot:xlabel='year', ylabel='estimated_revenue'>

# %%
plt.figure(figsize=(12,6))

sns.lineplot(x='day',y='estimated_revenue',data=listings,marker='o',markersize=6)
plt.xticks(np.arange(1,32,1))
# Out:
# ([<matplotlib.axis.XTick at 0x2301e2efc48>,
#   <matplotlib.axis.XTick at 0x2301e6b4088>,
#   <matplotlib.axis.XTick at 0x2301e5b00c8>,
#   <matplotlib.axis.XTick at 0x2301e2b1908>,
#   <matplotlib.axis.XTick at 0x2301e2b1a48>,
#   <matplotlib.axis.XTick at 0x2301e5d9408>,
#   <matplotlib.axis.XTick at 0x2301e5d9a48>,
#   <matplotlib.axis.XTick at 0x2301e5b4488>,
#   <matplotlib.axis.XTick at 0x2301e5d2188>,
#   <matplotlib.axis.XTick at 0x2301e687c48>,
#   <matplotlib.axis.XTick at 0x2301bf83648>,
#   <matplotlib.axis.XTick at 0x2301bec1988>,
#   <matplotlib.axis.XTick at 0x2301e5a07c8>,
#   <matplotlib.axis.XTick at 0x2301e5d2d88>,
#   <matplotlib.axis.XTick at 0x2301e1ddc88>,
#   <matplotlib.axis.XTick at 0x2301e1fe888>,
#   <matplotlib.axis.XTick at 0x2301c059308>,
#   <matplotlib.axis.XTick at 0x2301e549dc8>,
#   <matplotlib.axis.XTick at 0x2301e5576c8>,
#   <matplotlib.axis.XTick at 0x2301bea1548>,
#   <matplotlib.axis.XTick at 0x2301e55de08>,
#   <matplotlib.axis.XTick at 0x2301beb7048>,
#   <matplotlib.axis.XTick at 0x2301e5d2f48>,
#   <matplotlib.axis.XTick at 0x2301bfec5c8>,
#   <matplotlib.axis.XTick at 0x2301e55ecc8>,
#   <matplotlib.axis.XTick at 0x2301c09d408>,
#   <matplotlib.axis.XTick at 0x23019ab2248>,
#   <matplotlib.axis.XTick at 0x2301ab96508>,
#   <matplotlib.axis.XTick at 0x2301e227408>,
#   <matplotlib.axis.XTick at 0x2301ec27f88>,
#   <matplotlib.axis.XTick at 0x2301ab96f08>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#host_response_time
#host_acceptance_rate
#host_is_superhost
#host_has_profile_pic
#host_identity_verified
#neighbourhood_group_cleansed
#city
#state
#smart_location
#is_location_exact
#property_type
#room_type
#accommodates
#bathrooms
#bedrooms
#beds
#bed_type
#guests_included
#minimum_nights
#review_scores_accuracy
#review_scores_cleanliness
#review_scores_checkin
#review_scores_communication
#review_scores_location
#review_scores_value
#instant_bookable
#cancellation_policy
#require_guest_profile_picture
#require_guest_phone_verification
#calculated_host_listings_count

# %% [raw]
# This shows that Hosts can get more Revenue if they ask Guest Verification which could be bcz Customers may be appreciating that if they are asking for theire verification than they themselves will be ensuring safety and security

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
sns.countplot(x='require_guest_profile_picture',data=listings,ax=ax[0])
sns.barplot(x='require_guest_profile_picture',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
sns.countplot(x='require_guest_phone_verification',data=listings,ax=ax[0])
sns.barplot(x='require_guest_phone_verification',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %% [raw]
# It looks really unique for Hosts that if someone is thinking to put Cancellation Policies flexible in order to attract customers and earn more revenue which is quite normal somebody do but Seattle is really different bcz people looks really honest in cancellation policies and not want flexibilites even if they have to pay more for Tight Rules

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
sns.countplot(x='cancellation_policy',data=listings,ax=ax[0])
sns.barplot(x='cancellation_policy',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %% [raw]
# Although we are analyzing Seattle Only but it also have some areas and although you may laugh because here "Seattle, WA","Seattle , WA "  and "西雅图, WA " are all same i.e. Seattle as a whole city so nothing important but other areas are catully very specific and it gives us important insight that Future Hosts have good Oppurtinity of Good Earnings if thaey belong to Phinney Ridge Seattle, WA

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(24,5))
sns.countplot(x='city',data=listings,ax=ax[0])
sns.barplot(x='city',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
listings['city'].value_counts()
# Out:
# Seattle                  84667
# Ballard, Seattle            74
# West Seattle                40
# Seattle                     30
# 西雅图                         27
# Phinney Ridge Seattle       11
# Name: city, dtype: int64

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(24,5))
sns.countplot(x='is_location_exact',data=listings,ax=ax[0])
sns.barplot(x='is_location_exact',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %% [raw]
# It is showing that Customer generally prefer Host with Instant Booking Availablity, Thus future hosts must be very agile if they really want to get really good revenue outcomes

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(24,5))
sns.countplot(x='instant_bookable',data=listings,ax=ax[0])
sns.barplot(x='instant_bookable',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(24,10))
sns.countplot(x='review_scores_communication',data=listings,ax=ax[0])
sns.barplot(x='review_scores_communication',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(24,10))
sns.countplot(x='review_scores_checkin',data=listings,ax=ax[0])
sns.barplot(x='review_scores_checkin',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(24,10))
sns.countplot(x='review_scores_location',data=listings,ax=ax[0])
sns.barplot(x='review_scores_location',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(24,10))
sns.countplot(x='review_scores_accuracy',data=listings,ax=ax[0])
sns.barplot(x='review_scores_accuracy',y='estimated_revenue',data=listings,ax=ax[1])
plt.tight_layout()

# %% [markdown]
# Reviews Data

# %%
reviews
# Out:
#        listing_id        id       date  reviewer_id reviewer_name  \
# 0         7202016  38917982 2015-07-19     28943674        Bianca
# 1         7202016  39087409 2015-07-20     32440555         Frank
# 2         7202016  39820030 2015-07-26     37722850           Ian
# 3         7202016  40813543 2015-08-02     33671805        George
# 4         7202016  41986501 2015-08-10     34959538          Ming
# ...           ...       ...        ...          ...           ...
# 84844     3624990  50436321 2015-10-12     37419458          Ryan
# 84845     3624990  51024875 2015-10-17      6933252         Linda
# 84846     3624990  51511988 2015-10-20     19543701         Jaime
# 84847     3624990  52814482 2015-11-02     24445024        Jørgen
# 84848     9727246  56429621 2015-12-13     30860360     Stephanie
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# 1      Kelly has a great room in a very central locat...
# 2      Very spacious apartment, and in a great neighb...
# 3      Close to Seattle Center and all it has to offe...
# 4      Kelly was a great host and very accommodating ...
# ...                                                  ...
# 84844  The description and pictures of the apartment ...
# 84845  We had an excellent stay. It was clean and com...
# 84846  Gran ubicación, cerca de todo lo atractivo del...
# 84847  Very good apartement, clean and well sized. Si...
# 84848  Breanne was a great host. Check in was easy, s...
#
# [84849 rows x 6 columns]

# %%
series2 = reviews.date.value_counts()

# %%
series2
# Out:
# 2015-09-21    580
# 2015-08-07    400
# 2015-09-07    384
# 2015-08-10    383
# 2015-08-31    371
#              ...
# 2009-10-02      1
# 2010-10-15      1
# 2011-04-22      1
# 2011-03-01      1
# 2015-11-30      1
# Name: date, Length: 1930, dtype: int64

# %%
#This Visualization is just for Exploration (No Insight)
import matplotlib.dates as mdates
plt.figure(figsize=(12,6))
myFmt = mdates.DateFormatter('%y-%m-%d') # here you can format your datetick labels as desired
plt.plot_date(series2.index,series2.values)
plt.gca().xaxis.set_major_formatter(myFmt)
plt.xticks()
# Out:
# (array([14245., 14610., 14975., 15340., 15706., 16071., 16436., 16801.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
reviews['year'] = reviews['date'].apply(lambda x: x.year)
reviews['month'] = reviews['date'].apply(lambda x: x.month)
reviews['day'] = reviews['date'].apply(lambda x: x.day)

# %%
#This Visualization is just for Exploration (No Insight)
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(24,6))
sns.countplot(x='day',data=reviews,ax=ax[0])
sns.countplot(x='month',data=reviews,ax=ax[1])
plt.xticks(np.arange(1,13,1))
# Out:
# ([<matplotlib.axis.XTick at 0x230273d0408>,
#   <matplotlib.axis.XTick at 0x230273915c8>,
#   <matplotlib.axis.XTick at 0x23027391e08>,
#   <matplotlib.axis.XTick at 0x23022d19788>,
#   <matplotlib.axis.XTick at 0x23022dbf588>,
#   <matplotlib.axis.XTick at 0x23022dbf088>,
#   <matplotlib.axis.XTick at 0x23022d1e088>,
#   <matplotlib.axis.XTick at 0x23022d1e248>,
#   <matplotlib.axis.XTick at 0x23022ce9d48>,
#   <matplotlib.axis.XTick at 0x23022ce9c88>,
#   <matplotlib.axis.XTick at 0x23022b1b488>,
#   <matplotlib.axis.XTick at 0x23022b07708>],
#  [Text(0, 0, '1'),
#   Text(1, 0, '2'),
#   Text(2, 0, '3'),
#   Text(3, 0, '4'),
#   Text(4, 0, '5'),
#   Text(5, 0, '6'),
#   Text(6, 0, '7'),
#   Text(7, 0, '8'),
#   Text(8, 0, '9'),
#   Text(9, 0, '10'),
#   Text(10, 0, '11'),
#   Text(11, 0, '12')])

# %%
#This Visualization is just for Exploration (No Insight)
sns.countplot(x='year',data=reviews)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %% [raw]
# Here are few insights for Hosts to get Good Revenues -
#
# 1. Most Current Hosts are located at zipcodes (98103, 98122 and 98102) but if we look at estimated revenue then it doesn't look that much high but there are very good other zip code locations in Seattle which actually don't have much hosts but the estimated revenue seems quite ood as compared to top 3 zip codes. Those Potential Zip Codes are 98101, 98121, 98105, 98119, 98109, 98144, 98116, 98199, 98121

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='zipcode',data=listings)
plt.tight_layout()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='zipcode',y='estimated_revenue',data=listings,)
plt.tight_layout()

# %%
listings['zipcode'].value_counts()
# Out:
# 98103        9169
# 98122        8846
# 98102        8295
# 98107        5685
# 98117        4551
# 98144        4524
# 98118        4413
# 98121        4189
# 98101        4012
# 98104        3806
# 98112        3655
# 98119        3568
# 98115        3474
# 98109        3346
# 98105        2771
# 98106        1794
# 98116        1702
# 98108        1467
# 98136        1270
# 98125        1001
# 98199         999
# 98126         802
# 98133         618
# 98177         228
# 98178         209
# 98134         196
# 98146          46
# 99\n98122       1
# Name: zipcode, dtype: int64

# %% [markdown]
# ## Step 3 - Preparation of Data (Missing Values) (Assess, Clean)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84849 entries, 0 to 84848
# Data columns (total 97 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_id                        84849 non-null  int64
#  1   listing_url                       84849 non-null  object
#  2   name                              84849 non-null  object
#  3   summary                           75850 non-null  object
#  4   space                             81901 non-null  object
#  5   description                       84849 non-null  object
#  6   neighborhood_overview             66434 non-null  object
#  7   notes                             56690 non-null  object
#  8   transit                           70120 non-null  object
#  9   thumbnail_url                     79801 non-null  object
#  10  medium_url                        79801 non-null  object
#  11  picture_url                       84849 non-null  object
#  12  xl_picture_url                    79801 non-null  object
#  13  host_id                           84849 non-null  int64
#  14  host_url                          84849 non-null  object
#  15  host_name                         84849 non-null  object
#  16  host_since                        84849 non-null  datetime64[ns]
#  17  host_location                     84849 non-null  object
#  18  host_about                        78173 non-null  object
#  19  host_response_time                81210 non-null  object
#  20  host_response_rate                81210 non-null  float64
#  21  host_acceptance_rate              79409 non-null  float64
#  22  host_is_superhost                 84849 non-null  object
#  23  host_thumbnail_url                84849 non-null  object
#  24  host_picture_url                  84849 non-null  object
#  25  host_neighbourhood                81968 non-null  object
#  26  host_listings_count               84849 non-null  float64
#  27  host_total_listings_count         84849 non-null  float64
#  28  host_verifications                84849 non-null  object
#  29  host_has_profile_pic              84849 non-null  object
#  30  host_identity_verified            84849 non-null  object
#  31  street                            84849 non-null  object
#  32  neighbourhood                     80190 non-null  object
#  33  neighbourhood_cleansed            84849 non-null  object
#  34  neighbourhood_group_cleansed      84849 non-null  object
#  35  city                              84849 non-null  object
#  36  zipcode                           84637 non-null  object
#  37  latitude                          84849 non-null  float64
#  38  longitude                         84849 non-null  float64
#  39  is_location_exact                 84849 non-null  object
#  40  property_type                     84849 non-null  object
#  41  room_type                         84849 non-null  object
#  42  accommodates                      84849 non-null  int64
#  43  bathrooms                         84240 non-null  float64
#  44  bedrooms                          84559 non-null  float64
#  45  beds                              84849 non-null  float64
#  46  bed_type                          84849 non-null  object
#  47  amenities                         84849 non-null  object
#  48  square_feet                       4252 non-null   float64
#  49  price                             84849 non-null  float64
#  50  weekly_price                      46362 non-null  float64
#  51  monthly_price                     36088 non-null  float64
#  52  security_deposit                  42116 non-null  float64
#  53  cleaning_fee                      61310 non-null  float64
#  54  guests_included                   84849 non-null  int64
#  55  extra_people                      84849 non-null  float64
#  56  minimum_nights                    84849 non-null  int64
#  57  maximum_nights                    84849 non-null  int64
#  58  calendar_updated                  84849 non-null  object
#  59  availability_30                   84849 non-null  int64
#  60  availability_60                   84849 non-null  int64
#  61  availability_90                   84849 non-null  int64
#  62  availability_365                  84849 non-null  int64
#  63  number_of_reviews                 84849 non-null  int64
#  64  first_review                      84849 non-null  datetime64[ns]
#  65  last_review                       84849 non-null  datetime64[ns]
#  66  review_scores_rating              84829 non-null  float64
#  67  review_scores_accuracy            84815 non-null  float64
#  68  review_scores_cleanliness         84822 non-null  float64
#  69  review_scores_checkin             84815 non-null  float64
#  70  review_scores_communication       84824 non-null  float64
#  71  review_scores_location            84818 non-null  float64
#  72  review_scores_value               84817 non-null  float64
#  73  instant_bookable                  84849 non-null  object
#  74  cancellation_policy               84849 non-null  object
#  75  require_guest_profile_picture     84849 non-null  object
#  76  require_guest_phone_verification  84849 non-null  object
#  77  calculated_host_listings_count    84849 non-null  int64
#  78  reviews_per_month                 84849 non-null  float64
#  79  id                                84849 non-null  int64
#  80  date                              84849 non-null  datetime64[ns]
#  81  reviewer_id                       84849 non-null  int64
#  82  reviewer_name                     84849 non-null  object
#  83  comments                          84831 non-null  object
#  84  estimated_revenue                 84849 non-null  float64
#  85  year                              84849 non-null  int64
#  86  month                             84849 non-null  int64
#  87  day                               84849 non-null  int64
#  88  host_since_year                   84849 non-null  int64
#  89  host_since_month                  84849 non-null  int64
#  90  host_since_day                    84849 non-null  int64
#  91  first_review_year                 84849 non-null  int64
#  92  first_review_month                84849 non-null  int64
#  93  first_review_day                  84849 non-null  int64
#  94  last_review_year                  84849 non-null  int64
#  95  last_review_month                 84849 non-null  int64
#  96  last_review_day                   84849 non-null  int64
# dtypes: datetime64[ns](4), float64(25), int64(26), object(42)
# memory usage: 65.9+ MB

# %%
listings.columns[listings.isna().any()]
# Out:
# Index(['summary', 'space', 'neighborhood_overview', 'notes', 'transit',
#        'thumbnail_url', 'medium_url', 'xl_picture_url', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_neighbourhood', 'neighbourhood', 'zipcode', 'bathrooms',
#        'bedrooms', 'square_feet', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'comments'],
#       dtype='object')

# %%
x = np.sum(listings.isna())

# %%
plt.figure(figsize=(15,8))
x[x>0].plot(kind='bar')
plt.tight_layout()

# %% [raw]
# There are few columns like "square_feet", "weekly_price", "monthly_price", "security_deposit" which are Numerical Columns so we could have replaced missing values by suitable imputation but since missing value percent are greater than 40 percent of total entries, so if we do imputation than we may loose the unique capablities of features which in turn will harm our Model Accuracy so we will xclude all missing values

# %%
x = x/84849*100
plt.figure(figsize=(15,6))
x[x>0].plot(kind='bar')
plt.tight_layout()

# %%
listings.drop(axis=1,labels=['square_feet','weekly_price','monthly_price','security_deposit'],inplace=True)

# %%
listings['neighborhood_overview']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 84844    It's taken me a while to figure out why Fremon...
# 84845    It's taken me a while to figure out why Fremon...
# 84846    We're located near lots of family fun. Woodlan...
# 84847    The neighborhood is a quiet oasis that is clos...
# 84848    The neighborhood is a quiet oasis that is clos...
# Name: neighborhood_overview, Length: 84849, dtype: object

# %%
x2 = np.sum(listings.isna())
x2 = x2/84849*100

# %%
plt.figure(figsize=(15,6))
x2[x2>0].plot(kind='bar')
plt.tight_layout()

# %% [raw]
# There are few other columns like listing_id, summary etc which are either descriptive or unique values for each row so we exclude these columns.

# %%
listings.drop(axis=1,labels=['summary','notes','medium_url','thumbnail_url','xl_picture_url','listing_url'
                            ,'listing_id','name','space','description','neighborhood_overview','transit','id'
                            ,'comments','reviewer_name','reviewer_id','date','host_since','last_review','first_review','host_id','host_url','picture_url'
                            ,'host_about','host_thumbnail_url','host_picture_url','amenities','host_name','latitude'
                             ,'longitude','street','host_location','host_verifications','calendar_updated'
                            ,'neighbourhood','neighbourhood_cleansed'],inplace=True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84849 entries, 0 to 84848
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                81210 non-null  object
#  1   host_response_rate                81210 non-null  float64
#  2   host_acceptance_rate              79409 non-null  float64
#  3   host_is_superhost                 84849 non-null  object
#  4   host_neighbourhood                81968 non-null  object
#  5   host_listings_count               84849 non-null  float64
#  6   host_total_listings_count         84849 non-null  float64
#  7   host_has_profile_pic              84849 non-null  object
#  8   host_identity_verified            84849 non-null  object
#  9   neighbourhood_group_cleansed      84849 non-null  object
#  10  city                              84849 non-null  object
#  11  zipcode                           84637 non-null  object
#  12  is_location_exact                 84849 non-null  object
#  13  property_type                     84849 non-null  object
#  14  room_type                         84849 non-null  object
#  15  accommodates                      84849 non-null  int64
#  16  bathrooms                         84240 non-null  float64
#  17  bedrooms                          84559 non-null  float64
#  18  beds                              84849 non-null  float64
#  19  bed_type                          84849 non-null  object
#  20  price                             84849 non-null  float64
#  21  cleaning_fee                      61310 non-null  float64
#  22  guests_included                   84849 non-null  int64
#  23  extra_people                      84849 non-null  float64
#  24  minimum_nights                    84849 non-null  int64
#  25  maximum_nights                    84849 non-null  int64
#  26  availability_30                   84849 non-null  int64
#  27  availability_60                   84849 non-null  int64
#  28  availability_90                   84849 non-null  int64
#  29  availability_365                  84849 non-null  int64
#  30  number_of_reviews                 84849 non-null  int64
#  31  review_scores_rating              84829 non-null  float64
#  32  review_scores_accuracy            84815 non-null  float64
#  33  review_scores_cleanliness         84822 non-null  float64
#  34  review_scores_checkin             84815 non-null  float64
#  35  review_scores_communication       84824 non-null  float64
#  36  review_scores_location            84818 non-null  float64
#  37  review_scores_value               84817 non-null  float64
#  38  instant_bookable                  84849 non-null  object
#  39  cancellation_policy               84849 non-null  object
#  40  require_guest_profile_picture     84849 non-null  object
#  41  require_guest_phone_verification  84849 non-null  object
#  42  calculated_host_listings_count    84849 non-null  int64
#  43  reviews_per_month                 84849 non-null  float64
#  44  estimated_revenue                 84849 non-null  float64
#  45  year                              84849 non-null  int64
#  46  month                             84849 non-null  int64
#  47  day                               84849 non-null  int64
#  48  host_since_year                   84849 non-null  int64
#  49  host_since_month                  84849 non-null  int64
#  50  host_since_day                    84849 non-null  int64
#  51  first_review_year                 84849 non-null  int64
#  52  first_review_month                84849 non-null  int64
#  53  first_review_day                  84849 non-null  int64
#  54  last_review_year                  84849 non-null  int64
#  55  last_review_month                 84849 non-null  int64
#  56  last_review_day                   84849 non-null  int64
# dtypes: float64(19), int64(22), object(16)
# memory usage: 40.0+ MB

# %%
listings['zipcode'].value_counts()
# Out:
# 98103        9169
# 98122        8846
# 98102        8295
# 98107        5685
# 98117        4551
# 98144        4524
# 98118        4413
# 98121        4189
# 98101        4012
# 98104        3806
# 98112        3655
# 98119        3568
# 98115        3474
# 98109        3346
# 98105        2771
# 98106        1794
# 98116        1702
# 98108        1467
# 98136        1270
# 98125        1001
# 98199         999
# 98126         802
# 98133         618
# 98177         228
# 98178         209
# 98134         196
# 98146          46
# 99\n98122       1
# Name: zipcode, dtype: int64

# %%
indexNames = listings[ listings['zipcode'] == '99\n98122' ].index

# %%
listings.drop(indexNames , inplace=True)

# %%
np.sum(listings['zipcode'].isna())
# Out:
# 212

# %%
listings['zipcode'].value_counts()
# Out:
# 98103    9169
# 98122    8846
# 98102    8295
# 98107    5685
# 98117    4551
# 98144    4524
# 98118    4413
# 98121    4189
# 98101    4012
# 98104    3806
# 98112    3655
# 98119    3568
# 98115    3474
# 98109    3346
# 98105    2771
# 98106    1794
# 98116    1702
# 98108    1467
# 98136    1270
# 98125    1001
# 98199     999
# 98126     802
# 98133     618
# 98177     228
# 98178     209
# 98134     196
# 98146      46
# Name: zipcode, dtype: int64

# %%
x3 = np.sum(listings.isna())
x3 = x3/84849*100

# %%
plt.figure(figsize=(15,6))
x3[x3>1].plot(kind='bar')
plt.tight_layout()

# %%
listings['cleaning_fee'].value_counts()
# Out:
# 25.0     6440
# 50.0     6139
# 10.0     5241
# 60.0     4280
# 30.0     4110
#          ...
# 230.0       1
# 134.0       1
# 165.0       1
# 117.0       1
# 185.0       1
# Name: cleaning_fee, Length: 115, dtype: int64

# %%
listings['cleaning_fee'].mean()
# Out:
# 48.05954982873919

# %% [raw]
# Dropping cleaning_fee missing values

# %%
plt.figure(figsize=(50,8))
sns.barplot(y='estimated_revenue',x='cleaning_fee',data=listings)
plt.tight_layout()

# %%
plt.figure(figsize=(50,8))
sns.countplot(x='cleaning_fee',data=listings)
plt.tight_layout()

# %%
listings['host_response_time'].value_counts()
# Out:
# within an hour        48870
# within a few hours    24050
# within a day           7846
# a few days or more      443
# Name: host_response_time, dtype: int64

# %%
listings['host_acceptance_rate'].value_counts()
# Out:
# 100.0    79402
# 0.0          6
# Name: host_acceptance_rate, dtype: int64

# %%
listings['host_response_rate'].value_counts()
# Out:
# 100.0    63557
# 90.0      4503
# 94.0      1286
# 80.0      1235
# 99.0      1165
# 86.0       992
# 93.0       787
# 75.0       690
# 97.0       688
# 96.0       635
# 95.0       595
# 70.0       580
# 98.0       572
# 88.0       529
# 89.0       423
# 50.0       399
# 83.0       361
# 92.0       359
# 67.0       333
# 60.0       294
# 71.0       156
# 33.0       154
# 43.0       148
# 91.0       132
# 40.0       120
# 63.0       118
# 53.0        96
# 78.0        92
# 82.0        45
# 69.0        39
# 76.0        30
# 81.0        29
# 57.0        18
# 87.0        10
# 25.0         8
# 64.0         7
# 58.0         7
# 31.0         7
# 17.0         3
# 56.0         2
# 30.0         2
# 65.0         2
# 38.0         1
# Name: host_response_rate, dtype: int64

# %%
x['cleaning_fee']
# Out:
# 27.742224422208867

# %%
listings['cleaning_fee'].value_counts()
# Out:
# 25.0     6440
# 50.0     6139
# 10.0     5241
# 60.0     4280
# 30.0     4110
#          ...
# 230.0       1
# 134.0       1
# 165.0       1
# 117.0       1
# 185.0       1
# Name: cleaning_fee, Length: 115, dtype: int64

# %%
np.mean(listings['cleaning_fee'].value_counts().index)
# Out:
# 101.6

# %%
listings.columns[listings.nunique() == 0]
# Out:
# Index([], dtype='object')

# %%
len(listings.columns[listings.nunique() < 3818])
# Out:
# 57

# %%
listings['instant_bookable'].value_counts()
# Out:
# f    65302
# t    19546
# Name: instant_bookable, dtype: int64

# %%
listings.isna()
# Out:
#        host_response_time  host_response_rate  host_acceptance_rate  \
# 0                   False               False                 False
# 1                   False               False                 False
# 2                   False               False                 False
# 3                   False               False                 False
# 4                   False               False                 False
# ...                   ...                 ...                   ...
# 84844               False               False                 False
# 84845               False               False                 False
# 84846               False               False                 False
# 84847               False               False                 False
# 84848               False               False                 False
#
#        host_is_superhost  host_neighbourhood  host_listings_count  \
# 0                  False               False                False
# 1                  False               False                False
# 2                  False               False                False
# 3                  False               False                False
# 4                  False               False                False
# ...                  ...                 ...                  ...
# 84844              False               False                False
# 84845              False               False                False
# 84846              False               False                False
# 84847              False               False                False
# 84848              False               False                False
#
#        host_total_listings_count  host_has_profile_pic  \
# 0                          False                 False
# 1                          False                 False
# 2                          False                 False
# 3                          False                 False
# 4                          False                 False
# ...                          ...                   ...
# 84844                      False                 False
# 84845                      False                 False
# 84846                      False                 False
# 84847                      False                 False
# 84848                      False                 False
#
#        host_identity_verified  neighbourhood_group_cleansed  ...    day  \
# 0                       False                         False  ...  False
# 1                       False                         False  ...  False
# 2                       False                         False  ...  False
# 3                       False                         False  ...  False
# 4                       False                         False  ...  False
# ...                       ...                           ...  ...    ...
# 84844                   False                         False  ...  False
# 84845                   False                         False  ...  False
# 84846                   False                         False  ...  False
# 84847                   False                         False  ...  False
# 84848                   False                         False  ...  False
#
#        host_since_year  host_since_month  host_since_day  first_review_year  \
# 0                False             False           False              False
# 1                False             False           False              False
# 2                False             False           False              False
# 3                False             False           False              False
# 4                False             False           False              False
# ...                ...               ...             ...                ...
# 84844            False             False           False              False
# 84845            False             False           False              False
# 84846            False             False           False              False
# 84847            False             False           False              False
# 84848            False             False           False              False
#
#        first_review_month  first_review_day  last_review_year  \
# 0                   False             False             False
# 1                   False             False             False
# 2                   False             False             False
# 3                   False             False             False
# 4                   False             False             False
# ...                   ...               ...               ...
# 84844               False             False             False
# 84845               False             False             False
# 84846               False             False             False
# 84847               False             False             False
# 84848               False             False             False
#
#        last_review_month  last_review_day
# 0                  False            False
# 1                  False            False
# 2                  False            False
# 3                  False            False
# 4                  False            False
# ...                  ...              ...
# 84844              False            False
# 84845              False            False
# 84846              False            False
# 84847              False            False
# 84848              False            False
#
# [84848 rows x 57 columns]

# %%
listings.isnull()
# Out:
#        host_response_time  host_response_rate  host_acceptance_rate  \
# 0                   False               False                 False
# 1                   False               False                 False
# 2                   False               False                 False
# 3                   False               False                 False
# 4                   False               False                 False
# ...                   ...                 ...                   ...
# 84844               False               False                 False
# 84845               False               False                 False
# 84846               False               False                 False
# 84847               False               False                 False
# 84848               False               False                 False
#
#        host_is_superhost  host_neighbourhood  host_listings_count  \
# 0                  False               False                False
# 1                  False               False                False
# 2                  False               False                False
# 3                  False               False                False
# 4                  False               False                False
# ...                  ...                 ...                  ...
# 84844              False               False                False
# 84845              False               False                False
# 84846              False               False                False
# 84847              False               False                False
# 84848              False               False                False
#
#        host_total_listings_count  host_has_profile_pic  \
# 0                          False                 False
# 1                          False                 False
# 2                          False                 False
# 3                          False                 False
# 4                          False                 False
# ...                          ...                   ...
# 84844                      False                 False
# 84845                      False                 False
# 84846                      False                 False
# 84847                      False                 False
# 84848                      False                 False
#
#        host_identity_verified  neighbourhood_group_cleansed  ...    day  \
# 0                       False                         False  ...  False
# 1                       False                         False  ...  False
# 2                       False                         False  ...  False
# 3                       False                         False  ...  False
# 4                       False                         False  ...  False
# ...                       ...                           ...  ...    ...
# 84844                   False                         False  ...  False
# 84845                   False                         False  ...  False
# 84846                   False                         False  ...  False
# 84847                   False                         False  ...  False
# 84848                   False                         False  ...  False
#
#        host_since_year  host_since_month  host_since_day  first_review_year  \
# 0                False             False           False              False
# 1                False             False           False              False
# 2                False             False           False              False
# 3                False             False           False              False
# 4                False             False           False              False
# ...                ...               ...             ...                ...
# 84844            False             False           False              False
# 84845            False             False           False              False
# 84846            False             False           False              False
# 84847            False             False           False              False
# 84848            False             False           False              False
#
#        first_review_month  first_review_day  last_review_year  \
# 0                   False             False             False
# 1                   False             False             False
# 2                   False             False             False
# 3                   False             False             False
# 4                   False             False             False
# ...                   ...               ...               ...
# 84844               False             False             False
# 84845               False             False             False
# 84846               False             False             False
# 84847               False             False             False
# 84848               False             False             False
#
#        last_review_month  last_review_day
# 0                  False            False
# 1                  False            False
# 2                  False            False
# 3                  False            False
# 4                  False            False
# ...                  ...              ...
# 84844              False            False
# 84845              False            False
# 84846              False            False
# 84847              False            False
# 84848              False            False
#
# [84848 rows x 57 columns]

# %% [markdown]
# Now let us Drop the rows that have NaN Values in Particular Columns. Columns I choose are basically all related to Review because it is going to be the Feature for which we are going to create Predictve Model

# %%
listings.dropna(subset=['zipcode','cleaning_fee','host_neighbourhood'],inplace=True)

# %%
listings['zipcode'] = listings['zipcode'].astype(int)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59267 entries, 207 to 84848
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                56746 non-null  object
#  1   host_response_rate                56746 non-null  float64
#  2   host_acceptance_rate              55480 non-null  float64
#  3   host_is_superhost                 59267 non-null  object
#  4   host_neighbourhood                59267 non-null  object
#  5   host_listings_count               59267 non-null  float64
#  6   host_total_listings_count         59267 non-null  float64
#  7   host_has_profile_pic              59267 non-null  object
#  8   host_identity_verified            59267 non-null  object
#  9   neighbourhood_group_cleansed      59267 non-null  object
#  10  city                              59267 non-null  object
#  11  zipcode                           59267 non-null  int32
#  12  is_location_exact                 59267 non-null  object
#  13  property_type                     59267 non-null  object
#  14  room_type                         59267 non-null  object
#  15  accommodates                      59267 non-null  int64
#  16  bathrooms                         58936 non-null  float64
#  17  bedrooms                          59075 non-null  float64
#  18  beds                              59267 non-null  float64
#  19  bed_type                          59267 non-null  object
#  20  price                             59267 non-null  float64
#  21  cleaning_fee                      59267 non-null  float64
#  22  guests_included                   59267 non-null  int64
#  23  extra_people                      59267 non-null  float64
#  24  minimum_nights                    59267 non-null  int64
#  25  maximum_nights                    59267 non-null  int64
#  26  availability_30                   59267 non-null  int64
#  27  availability_60                   59267 non-null  int64
#  28  availability_90                   59267 non-null  int64
#  29  availability_365                  59267 non-null  int64
#  30  number_of_reviews                 59267 non-null  int64
#  31  review_scores_rating              59256 non-null  float64
#  32  review_scores_accuracy            59249 non-null  float64
#  33  review_scores_cleanliness         59255 non-null  float64
#  34  review_scores_checkin             59249 non-null  float64
#  35  review_scores_communication       59255 non-null  float64
#  36  review_scores_location            59250 non-null  float64
#  37  review_scores_value               59250 non-null  float64
#  38  instant_bookable                  59267 non-null  object
#  39  cancellation_policy               59267 non-null  object
#  40  require_guest_profile_picture     59267 non-null  object
#  41  require_guest_phone_verification  59267 non-null  object
#  42  calculated_host_listings_count    59267 non-null  int64
#  43  reviews_per_month                 59267 non-null  float64
#  44  estimated_revenue                 59267 non-null  float64
#  45  year                              59267 non-null  int64
#  46  month                             59267 non-null  int64
#  47  day                               59267 non-null  int64
#  48  host_since_year                   59267 non-null  int64
#  49  host_since_month                  59267 non-null  int64
#  50  host_since_day                    59267 non-null  int64
#  51  first_review_year                 59267 non-null  int64
#  52  first_review_month                59267 non-null  int64
#  53  first_review_day                  59267 non-null  int64
#  54  last_review_year                  59267 non-null  int64
#  55  last_review_month                 59267 non-null  int64
#  56  last_review_day                   59267 non-null  int64
# dtypes: float64(19), int32(1), int64(22), object(15)
# memory usage: 26.0+ MB

# %%
np.sum(listings.isna())
# Out:
# host_response_time                  2521
# host_response_rate                  2521
# host_acceptance_rate                3787
# host_is_superhost                      0
# host_neighbourhood                     0
# host_listings_count                    0
# host_total_listings_count              0
# host_has_profile_pic                   0
# host_identity_verified                 0
# neighbourhood_group_cleansed           0
# city                                   0
# zipcode                                0
# is_location_exact                      0
# property_type                          0
# room_type                              0
# accommodates                           0
# bathrooms                            331
# bedrooms                             192
# beds                                   0
# bed_type                               0
# price                                  0
# cleaning_fee                           0
# guests_included                        0
# extra_people                           0
# minimum_nights                         0
# maximum_nights                         0
# availability_30                        0
# availability_60                        0
# availability_90                        0
# availability_365                       0
# number_of_reviews                      0
# review_scores_rating                  11
# review_scores_accuracy                18
# review_scores_cleanliness             12
# review_scores_checkin                 18
# review_scores_communication           12
# review_scores_location                17
# review_scores_value                   17
# instant_bookable                       0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                      0
# estimated_revenue                      0
# year                                   0
# month                                  0
# day                                    0
# host_since_year                        0
# host_since_month                       0
# host_since_day                         0
# first_review_year                      0
# first_review_month                     0
# first_review_day                       0
# last_review_year                       0
# last_review_month                      0
# last_review_day                        0
# dtype: int64

# %% [raw]
# 'host_response_rate' replace by constant (Mean- 97)
# 'host_acceptance_rate' replace by constant (100)
# 'review_score_rating' replace by constant (Mean- 95)

# %% [raw]
# from sklearn.impute import SimpleImputer
#
# imputer_host_response_rate = SimpleImputer(strategy='constant',fill_value=97)
# imputer_host_acceptance_rate = SimpleImputer(strategy='constant',fill_value=100)
# imputer_frequent = SimpleImputer(strategy='most_frequent')
# imputer_review_score_rating = SimpleImputer(strategy='constant',fill_value=95)

# %% [raw]
# listings['host_response_rate'] = imputer_host_response_rate.fit_transform(listings['host_response_rate'])
# listings['host_acceptance_rate'] = imputer_host_acceptance_rate.fit_transform(listings['host_acceptance_rate'])
# listings['bathrooms'] = imputer_frequent.fit_transform(listings['bathrooms'])
# listings['bedrooms'] = imputer_frequent.fit_transform(listings['bedrooms'])
# listings['review_scores_accuracy'] = imputer_frequent.fit_transform(listings['review_scores_accuracy'])
# listings['review_scores_checkin'] = imputer_frequent.fit_transform(listings['review_scores_checkin'])
# listings['review_scores_cleanliness'] = imputer_frequent.fit_transform(listings['review_scores_cleanliness'])
# listings['review_scores_location'] = imputer_frequent.fit_transform(listings['review_scores_location'])
# listings['review_scores_value'] = imputer_frequent.fit_transform(listings['review_scores_value'])
# listings['review_scores_rating'] = imputer_review_score_rating.fit_transform(listings['review_scores_rating'])

# %%
listings.head()
# Out:
#     host_response_time  host_response_rate  host_acceptance_rate  \
# 207     within an hour                98.0                 100.0
# 208     within an hour                98.0                 100.0
# 209     within an hour                98.0                 100.0
# 210     within an hour                98.0                 100.0
# 211     within an hour                98.0                 100.0
#
#     host_is_superhost host_neighbourhood  host_listings_count  \
# 207                 t         Queen Anne                  6.0
# 208                 t         Queen Anne                  6.0
# 209                 t         Queen Anne                  6.0
# 210                 t         Queen Anne                  6.0
# 211                 t         Queen Anne                  6.0
#
#      host_total_listings_count host_has_profile_pic host_identity_verified  \
# 207                        6.0                    t                      t
# 208                        6.0                    t                      t
# 209                        6.0                    t                      t
# 210                        6.0                    t                      t
# 211                        6.0                    t                      t
#
#     neighbourhood_group_cleansed  ... day  host_since_year host_since_month  \
# 207                   Queen Anne  ...  19             2013                2
# 208                   Queen Anne  ...  19             2013                2
# 209                   Queen Anne  ...   1             2013                2
# 210                   Queen Anne  ...   1             2013                2
# 211                   Queen Anne  ...  10             2013                2
#
#     host_since_day first_review_year  first_review_month  first_review_day  \
# 207             21              2013                   8                19
# 208             21              2013                   8                19
# 209             21              2013                   8                19
# 210             21              2013                   8                19
# 211             21              2013                   8                19
#
#      last_review_year  last_review_month last_review_day
# 207              2015                 12              29
# 208              2015                 12              29
# 209              2015                 12              29
# 210              2015                 12              29
# 211              2015                 12              29
#
# [5 rows x 57 columns]

# %%
X = listings.loc[:, ~listings.columns.isin(['estimated_revenue'])].values

# %%
X2 = X

# %%
X
# Out:
# array([['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ...,
#        ['within a few hours', 99.0, 100.0, ..., 2015, 9, 27],
#        ['within an hour', 100.0, 100.0, ..., 2015, 12, 24],
#        ['within an hour', 100.0, 100.0, ..., 2015, 12, 24]], dtype=object)

# %%
y = listings.loc[:,'estimated_revenue'].values
y
# Out:
# array([ 300.,  300.,  300., ..., 1077.,  158.,  158.])

# %%
listings.loc[:, ~listings.columns.isin(['estimated_revenue'])].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59267 entries, 207 to 84848
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                56746 non-null  object
#  1   host_response_rate                56746 non-null  float64
#  2   host_acceptance_rate              55480 non-null  float64
#  3   host_is_superhost                 59267 non-null  object
#  4   host_neighbourhood                59267 non-null  object
#  5   host_listings_count               59267 non-null  float64
#  6   host_total_listings_count         59267 non-null  float64
#  7   host_has_profile_pic              59267 non-null  object
#  8   host_identity_verified            59267 non-null  object
#  9   neighbourhood_group_cleansed      59267 non-null  object
#  10  city                              59267 non-null  object
#  11  zipcode                           59267 non-null  int32
#  12  is_location_exact                 59267 non-null  object
#  13  property_type                     59267 non-null  object
#  14  room_type                         59267 non-null  object
#  15  accommodates                      59267 non-null  int64
#  16  bathrooms                         58936 non-null  float64
#  17  bedrooms                          59075 non-null  float64
#  18  beds                              59267 non-null  float64
#  19  bed_type                          59267 non-null  object
#  20  price                             59267 non-null  float64
#  21  cleaning_fee                      59267 non-null  float64
#  22  guests_included                   59267 non-null  int64
#  23  extra_people                      59267 non-null  float64
#  24  minimum_nights                    59267 non-null  int64
#  25  maximum_nights                    59267 non-null  int64
#  26  availability_30                   59267 non-null  int64
#  27  availability_60                   59267 non-null  int64
#  28  availability_90                   59267 non-null  int64
#  29  availability_365                  59267 non-null  int64
#  30  number_of_reviews                 59267 non-null  int64
#  31  review_scores_rating              59256 non-null  float64
#  32  review_scores_accuracy            59249 non-null  float64
#  33  review_scores_cleanliness         59255 non-null  float64
#  34  review_scores_checkin             59249 non-null  float64
#  35  review_scores_communication       59255 non-null  float64
#  36  review_scores_location            59250 non-null  float64
#  37  review_scores_value               59250 non-null  float64
#  38  instant_bookable                  59267 non-null  object
#  39  cancellation_policy               59267 non-null  object
#  40  require_guest_profile_picture     59267 non-null  object
#  41  require_guest_phone_verification  59267 non-null  object
#  42  calculated_host_listings_count    59267 non-null  int64
#  43  reviews_per_month                 59267 non-null  float64
#  44  year                              59267 non-null  int64
#  45  month                             59267 non-null  int64
#  46  day                               59267 non-null  int64
#  47  host_since_year                   59267 non-null  int64
#  48  host_since_month                  59267 non-null  int64
#  49  host_since_day                    59267 non-null  int64
#  50  first_review_year                 59267 non-null  int64
#  51  first_review_month                59267 non-null  int64
#  52  first_review_day                  59267 non-null  int64
#  53  last_review_year                  59267 non-null  int64
#  54  last_review_month                 59267 non-null  int64
#  55  last_review_day                   59267 non-null  int64
# dtypes: float64(18), int32(1), int64(22), object(15)
# memory usage: 25.5+ MB

# %%
X2
# Out:
# array([['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ...,
#        ['within a few hours', 99.0, 100.0, ..., 2015, 9, 27],
#        ['within an hour', 100.0, 100.0, ..., 2015, 12, 24],
#        ['within an hour', 100.0, 100.0, ..., 2015, 12, 24]], dtype=object)

# %%
listings.fillna(value={'host_response_rate':97,'host_acceptance_rate':100,'review_scores_rating':95
                      ,'review_scores_accuracy':listings['review_scores_accuracy'].mode()[0],
                       'review_scores_checkin':listings['review_scores_checkin'].mode()[0],
                       'review_scores_cleanliness':listings['review_scores_cleanliness'].mode()[0],
                      'review_scores_location':listings['review_scores_location'].mode()[0],
                      'review_scores_value':listings['review_scores_value'].mode()[0],
                      'bedrooms':listings['bedrooms'].mode()[0],
                      'bathrooms':listings['bathrooms'].mode()[0],
                      'review_scores_communication':listings['review_scores_communication'].mode()[0]
                      },inplace=True)

# %%
np.sum(listings.isna())
# Out:
# host_response_time                  2521
# host_response_rate                     0
# host_acceptance_rate                   0
# host_is_superhost                      0
# host_neighbourhood                     0
# host_listings_count                    0
# host_total_listings_count              0
# host_has_profile_pic                   0
# host_identity_verified                 0
# neighbourhood_group_cleansed           0
# city                                   0
# zipcode                                0
# is_location_exact                      0
# property_type                          0
# room_type                              0
# accommodates                           0
# bathrooms                              0
# bedrooms                               0
# beds                                   0
# bed_type                               0
# price                                  0
# cleaning_fee                           0
# guests_included                        0
# extra_people                           0
# minimum_nights                         0
# maximum_nights                         0
# availability_30                        0
# availability_60                        0
# availability_90                        0
# availability_365                       0
# number_of_reviews                      0
# review_scores_rating                   0
# review_scores_accuracy                 0
# review_scores_cleanliness              0
# review_scores_checkin                  0
# review_scores_communication            0
# review_scores_location                 0
# review_scores_value                    0
# instant_bookable                       0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                      0
# estimated_revenue                      0
# year                                   0
# month                                  0
# day                                    0
# host_since_year                        0
# host_since_month                       0
# host_since_day                         0
# first_review_year                      0
# first_review_month                     0
# first_review_day                       0
# last_review_year                       0
# last_review_month                      0
# last_review_day                        0
# dtype: int64

# %%
listings['host_response_rate'][listings['host_response_time'].isna()].value_counts()
# Out:
# 97.0    2521
# Name: host_response_rate, dtype: int64

# %%
listings['host_response_time'][listings['host_response_rate'] == 97].value_counts()
# Out:
# within a few hours    497
# within an hour         50
# Name: host_response_time, dtype: int64

# %%
listings.fillna(value={'host_response_time':'within a few hours'},inplace=True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59267 entries, 207 to 84848
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                59267 non-null  object
#  1   host_response_rate                59267 non-null  float64
#  2   host_acceptance_rate              59267 non-null  float64
#  3   host_is_superhost                 59267 non-null  object
#  4   host_neighbourhood                59267 non-null  object
#  5   host_listings_count               59267 non-null  float64
#  6   host_total_listings_count         59267 non-null  float64
#  7   host_has_profile_pic              59267 non-null  object
#  8   host_identity_verified            59267 non-null  object
#  9   neighbourhood_group_cleansed      59267 non-null  object
#  10  city                              59267 non-null  object
#  11  zipcode                           59267 non-null  int32
#  12  is_location_exact                 59267 non-null  object
#  13  property_type                     59267 non-null  object
#  14  room_type                         59267 non-null  object
#  15  accommodates                      59267 non-null  int64
#  16  bathrooms                         59267 non-null  float64
#  17  bedrooms                          59267 non-null  float64
#  18  beds                              59267 non-null  float64
#  19  bed_type                          59267 non-null  object
#  20  price                             59267 non-null  float64
#  21  cleaning_fee                      59267 non-null  float64
#  22  guests_included                   59267 non-null  int64
#  23  extra_people                      59267 non-null  float64
#  24  minimum_nights                    59267 non-null  int64
#  25  maximum_nights                    59267 non-null  int64
#  26  availability_30                   59267 non-null  int64
#  27  availability_60                   59267 non-null  int64
#  28  availability_90                   59267 non-null  int64
#  29  availability_365                  59267 non-null  int64
#  30  number_of_reviews                 59267 non-null  int64
#  31  review_scores_rating              59267 non-null  float64
#  32  review_scores_accuracy            59267 non-null  float64
#  33  review_scores_cleanliness         59267 non-null  float64
#  34  review_scores_checkin             59267 non-null  float64
#  35  review_scores_communication       59267 non-null  float64
#  36  review_scores_location            59267 non-null  float64
#  37  review_scores_value               59267 non-null  float64
#  38  instant_bookable                  59267 non-null  object
#  39  cancellation_policy               59267 non-null  object
#  40  require_guest_profile_picture     59267 non-null  object
#  41  require_guest_phone_verification  59267 non-null  object
#  42  calculated_host_listings_count    59267 non-null  int64
#  43  reviews_per_month                 59267 non-null  float64
#  44  estimated_revenue                 59267 non-null  float64
#  45  year                              59267 non-null  int64
#  46  month                             59267 non-null  int64
#  47  day                               59267 non-null  int64
#  48  host_since_year                   59267 non-null  int64
#  49  host_since_month                  59267 non-null  int64
#  50  host_since_day                    59267 non-null  int64
#  51  first_review_year                 59267 non-null  int64
#  52  first_review_month                59267 non-null  int64
#  53  first_review_day                  59267 non-null  int64
#  54  last_review_year                  59267 non-null  int64
#  55  last_review_month                 59267 non-null  int64
#  56  last_review_day                   59267 non-null  int64
# dtypes: float64(19), int32(1), int64(22), object(15)
# memory usage: 26.0+ MB

# %% [markdown]
# ## Step 4 - Building a Predictive Model to Estimate Revenue (Model)

# %%
listings.head()
# Out:
#     host_response_time  host_response_rate  host_acceptance_rate  \
# 207     within an hour                98.0                 100.0
# 208     within an hour                98.0                 100.0
# 209     within an hour                98.0                 100.0
# 210     within an hour                98.0                 100.0
# 211     within an hour                98.0                 100.0
#
#     host_is_superhost host_neighbourhood  host_listings_count  \
# 207                 t         Queen Anne                  6.0
# 208                 t         Queen Anne                  6.0
# 209                 t         Queen Anne                  6.0
# 210                 t         Queen Anne                  6.0
# 211                 t         Queen Anne                  6.0
#
#      host_total_listings_count host_has_profile_pic host_identity_verified  \
# 207                        6.0                    t                      t
# 208                        6.0                    t                      t
# 209                        6.0                    t                      t
# 210                        6.0                    t                      t
# 211                        6.0                    t                      t
#
#     neighbourhood_group_cleansed  ... day  host_since_year host_since_month  \
# 207                   Queen Anne  ...  19             2013                2
# 208                   Queen Anne  ...  19             2013                2
# 209                   Queen Anne  ...   1             2013                2
# 210                   Queen Anne  ...   1             2013                2
# 211                   Queen Anne  ...  10             2013                2
#
#     host_since_day first_review_year  first_review_month  first_review_day  \
# 207             21              2013                   8                19
# 208             21              2013                   8                19
# 209             21              2013                   8                19
# 210             21              2013                   8                19
# 211             21              2013                   8                19
#
#      last_review_year  last_review_month last_review_day
# 207              2015                 12              29
# 208              2015                 12              29
# 209              2015                 12              29
# 210              2015                 12              29
# 211              2015                 12              29
#
# [5 rows x 57 columns]

# %% [raw]
# Now we split Prepared Data into Matrix of Features (X) and Dependent Variable Vector (y)

# %%
X = listings.loc[:, ~listings.columns.isin(['estimated_revenue'])].values

# %%
X
# Out:
# array([['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ['within an hour', 98.0, 100.0, ..., 2015, 12, 29],
#        ...,
#        ['within a few hours', 99.0, 100.0, ..., 2015, 9, 27],
#        ['within an hour', 100.0, 100.0, ..., 2015, 12, 24],
#        ['within an hour', 100.0, 100.0, ..., 2015, 12, 24]], dtype=object)

# %%
y = listings.loc[:,'estimated_revenue'].values
y
# Out:
# array([ 300.,  300.,  300., ..., 1077.,  158.,  158.])

# %%
np.sum(listings == 't')
# Out:
# host_response_time                      0
# host_response_rate                      0
# host_acceptance_rate                    0
# host_is_superhost                   23121
# host_neighbourhood                      0
# host_listings_count                     0
# host_total_listings_count               0
# host_has_profile_pic                59253
# host_identity_verified              51147
# neighbourhood_group_cleansed            0
# city                                    0
# zipcode                                 0
# is_location_exact                   57354
# property_type                           0
# room_type                               0
# accommodates                            0
# bathrooms                               0
# bedrooms                                0
# beds                                    0
# bed_type                                0
# price                                   0
# cleaning_fee                            0
# guests_included                         0
# extra_people                            0
# minimum_nights                          0
# maximum_nights                          0
# availability_30                         0
# availability_60                         0
# availability_90                         0
# availability_365                        0
# number_of_reviews                       0
# review_scores_rating                    0
# review_scores_accuracy                  0
# review_scores_cleanliness               0
# review_scores_checkin                   0
# review_scores_communication             0
# review_scores_location                  0
# review_scores_value                     0
# instant_bookable                    15078
# cancellation_policy                     0
# require_guest_profile_picture       10552
# require_guest_phone_verification    12441
# calculated_host_listings_count          0
# reviews_per_month                       0
# estimated_revenue                       0
# year                                    0
# month                                   0
# day                                     0
# host_since_year                         0
# host_since_month                        0
# host_since_day                          0
# first_review_year                       0
# first_review_month                      0
# first_review_day                        0
# last_review_year                        0
# last_review_month                       0
# last_review_day                         0
# dtype: int64

# %%
listings.replace(to_replace={'t':1,'f':0},inplace=True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59267 entries, 207 to 84848
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                59267 non-null  object
#  1   host_response_rate                59267 non-null  float64
#  2   host_acceptance_rate              59267 non-null  float64
#  3   host_is_superhost                 59267 non-null  int64
#  4   host_neighbourhood                59267 non-null  object
#  5   host_listings_count               59267 non-null  float64
#  6   host_total_listings_count         59267 non-null  float64
#  7   host_has_profile_pic              59267 non-null  int64
#  8   host_identity_verified            59267 non-null  int64
#  9   neighbourhood_group_cleansed      59267 non-null  object
#  10  city                              59267 non-null  object
#  11  zipcode                           59267 non-null  int32
#  12  is_location_exact                 59267 non-null  int64
#  13  property_type                     59267 non-null  object
#  14  room_type                         59267 non-null  object
#  15  accommodates                      59267 non-null  int64
#  16  bathrooms                         59267 non-null  float64
#  17  bedrooms                          59267 non-null  float64
#  18  beds                              59267 non-null  float64
#  19  bed_type                          59267 non-null  object
#  20  price                             59267 non-null  float64
#  21  cleaning_fee                      59267 non-null  float64
#  22  guests_included                   59267 non-null  int64
#  23  extra_people                      59267 non-null  float64
#  24  minimum_nights                    59267 non-null  int64
#  25  maximum_nights                    59267 non-null  int64
#  26  availability_30                   59267 non-null  int64
#  27  availability_60                   59267 non-null  int64
#  28  availability_90                   59267 non-null  int64
#  29  availability_365                  59267 non-null  int64
#  30  number_of_reviews                 59267 non-null  int64
#  31  review_scores_rating              59267 non-null  float64
#  32  review_scores_accuracy            59267 non-null  float64
#  33  review_scores_cleanliness         59267 non-null  float64
#  34  review_scores_checkin             59267 non-null  float64
#  35  review_scores_communication       59267 non-null  float64
#  36  review_scores_location            59267 non-null  float64
#  37  review_scores_value               59267 non-null  float64
#  38  instant_bookable                  59267 non-null  int64
#  39  cancellation_policy               59267 non-null  object
#  40  require_guest_profile_picture     59267 non-null  int64
#  41  require_guest_phone_verification  59267 non-null  int64
#  42  calculated_host_listings_count    59267 non-null  int64
#  43  reviews_per_month                 59267 non-null  float64
#  44  estimated_revenue                 59267 non-null  float64
#  45  year                              59267 non-null  int64
#  46  month                             59267 non-null  int64
#  47  day                               59267 non-null  int64
#  48  host_since_year                   59267 non-null  int64
#  49  host_since_month                  59267 non-null  int64
#  50  host_since_day                    59267 non-null  int64
#  51  first_review_year                 59267 non-null  int64
#  52  first_review_month                59267 non-null  int64
#  53  first_review_day                  59267 non-null  int64
#  54  last_review_year                  59267 non-null  int64
#  55  last_review_month                 59267 non-null  int64
#  56  last_review_day                   59267 non-null  int64
# dtypes: float64(19), int32(1), int64(29), object(8)
# memory usage: 26.0+ MB

# %%
dummy = pd.get_dummies(columns=listings['property_type'],data=listings['property_type'],prefix='property_type'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy = listings['property_type']
listings.drop(axis=1,labels='property_type',inplace=True)

# %%
dummy
# Out:
#        property_type_Apartment  property_type_Bed & Breakfast  \
# 207                          1                              0
# 208                          1                              0
# 209                          1                              0
# 210                          1                              0
# 211                          1                              0
# ...                        ...                            ...
# 84771                        1                              0
# 84772                        1                              0
# 84846                        0                              0
# 84847                        1                              0
# 84848                        1                              0
#
#        property_type_Boat  property_type_Bungalow  property_type_Cabin  \
# 207                     0                       0                    0
# 208                     0                       0                    0
# 209                     0                       0                    0
# 210                     0                       0                    0
# 211                     0                       0                    0
# ...                   ...                     ...                  ...
# 84771                   0                       0                    0
# 84772                   0                       0                    0
# 84846                   0                       0                    0
# 84847                   0                       0                    0
# 84848                   0                       0                    0
#
#        property_type_Camper/RV  property_type_Chalet  \
# 207                          0                     0
# 208                          0                     0
# 209                          0                     0
# 210                          0                     0
# 211                          0                     0
# ...                        ...                   ...
# 84771                        0                     0
# 84772                        0                     0
# 84846                        0                     0
# 84847                        0                     0
# 84848                        0                     0
#
#        property_type_Condominium  property_type_Dorm  property_type_House  \
# 207                            0                   0                    0
# 208                            0                   0                    0
# 209                            0                   0                    0
# 210                            0                   0                    0
# 211                            0                   0                    0
# ...                          ...                 ...                  ...
# 84771                          0                   0                    0
# 84772                          0                   0                    0
# 84846                          0                   0                    1
# 84847                          0                   0                    0
# 84848                          0                   0                    0
#
#        property_type_Loft  property_type_Other  property_type_Townhouse  \
# 207                     0                    0                        0
# 208                     0                    0                        0
# 209                     0                    0                        0
# 210                     0                    0                        0
# 211                     0                    0                        0
# ...                   ...                  ...                      ...
# 84771                   0                    0                        0
# 84772                   0                    0                        0
# 84846                   0                    0                        0
# 84847                   0                    0                        0
# 84848                   0                    0                        0
#
#        property_type_Yurt
# 207                     0
# 208                     0
# 209                     0
# 210                     0
# 211                     0
# ...                   ...
# 84771                   0
# 84772                   0
# 84846                   0
# 84847                   0
# 84848                   0
#
# [59267 rows x 14 columns]

# %%
listings['zipcode'] = listings['zipcode'].astype(int)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59267 entries, 207 to 84848
# Data columns (total 70 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                59267 non-null  object
#  1   host_response_rate                59267 non-null  float64
#  2   host_acceptance_rate              59267 non-null  float64
#  3   host_is_superhost                 59267 non-null  int64
#  4   host_neighbourhood                59267 non-null  object
#  5   host_listings_count               59267 non-null  float64
#  6   host_total_listings_count         59267 non-null  float64
#  7   host_has_profile_pic              59267 non-null  int64
#  8   host_identity_verified            59267 non-null  int64
#  9   neighbourhood_group_cleansed      59267 non-null  object
#  10  city                              59267 non-null  object
#  11  zipcode                           59267 non-null  int32
#  12  is_location_exact                 59267 non-null  int64
#  13  room_type                         59267 non-null  object
#  14  accommodates                      59267 non-null  int64
#  15  bathrooms                         59267 non-null  float64
#  16  bedrooms                          59267 non-null  float64
#  17  beds                              59267 non-null  float64
#  18  bed_type                          59267 non-null  object
#  19  price                             59267 non-null  float64
#  20  cleaning_fee                      59267 non-null  float64
#  21  guests_included                   59267 non-null  int64
#  22  extra_people                      59267 non-null  float64
#  23  minimum_nights                    59267 non-null  int64
#  24  maximum_nights                    59267 non-null  int64
#  25  availability_30                   59267 non-null  int64
#  26  availability_60                   59267 non-null  int64
#  27  availability_90                   59267 non-null  int64
#  28  availability_365                  59267 non-null  int64
#  29  number_of_reviews                 59267 non-null  int64
#  30  review_scores_rating              59267 non-null  float64
#  31  review_scores_accuracy            59267 non-null  float64
#  32  review_scores_cleanliness         59267 non-null  float64
#  33  review_scores_checkin             59267 non-null  float64
#  34  review_scores_communication       59267 non-null  float64
#  35  review_scores_location            59267 non-null  float64
#  36  review_scores_value               59267 non-null  float64
#  37  instant_bookable                  59267 non-null  int64
#  38  cancellation_policy               59267 non-null  object
#  39  require_guest_profile_picture     59267 non-null  int64
#  40  require_guest_phone_verification  59267 non-null  int64
#  41  calculated_host_listings_count    59267 non-null  int64
#  42  reviews_per_month                 59267 non-null  float64
#  43  estimated_revenue                 59267 non-null  float64
#  44  year                              59267 non-null  int64
#  45  month                             59267 non-null  int64
#  46  day                               59267 non-null  int64
#  47  host_since_year                   59267 non-null  int64
#  48  host_since_month                  59267 non-null  int64
#  49  host_since_day                    59267 non-null  int64
#  50  first_review_year                 59267 non-null  int64
#  51  first_review_month                59267 non-null  int64
#  52  first_review_day                  59267 non-null  int64
#  53  last_review_year                  59267 non-null  int64
#  54  last_review_month                 59267 non-null  int64
#  55  last_review_day                   59267 non-null  int64
#  56  property_type_Apartment           59267 non-null  uint8
#  57  property_type_Bed & Breakfast     59267 non-null  uint8
#  58  property_type_Boat                59267 non-null  uint8
#  59  property_type_Bungalow            59267 non-null  uint8
#  60  property_type_Cabin               59267 non-null  uint8
#  61  property_type_Camper/RV           59267 non-null  uint8
#  62  property_type_Chalet              59267 non-null  uint8
#  63  property_type_Condominium         59267 non-null  uint8
#  64  property_type_Dorm                59267 non-null  uint8
#  65  property_type_House               59267 non-null  uint8
#  66  property_type_Loft                59267 non-null  uint8
#  67  property_type_Other               59267 non-null  uint8
#  68  property_type_Townhouse           59267 non-null  uint8
#  69  property_type_Yurt                59267 non-null  uint8
# dtypes: float64(19), int32(1), int64(29), object(7), uint8(14)
# memory usage: 28.8+ MB

# %%
dummy = pd.get_dummies(columns=listings['cancellation_policy'],data=listings['cancellation_policy'],prefix='cancellation_policy'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['cancellation_policy'] = listings['cancellation_policy']
listings.drop(axis=1,labels='cancellation_policy',inplace=True)

# %%
dummy = pd.get_dummies(columns=listings['bed_type'],data=listings['bed_type'],prefix='bed_type'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['bed_type'] = listings['bed_type']
listings.drop(axis=1,labels='bed_type',inplace=True)

# %%
dummy = pd.get_dummies(columns=listings['room_type'],data=listings['room_type'],prefix='room_type'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['room_type'] = listings['room_type']
listings.drop(axis=1,labels='room_type',inplace=True)

# %%
dummy = pd.get_dummies(columns=listings['city'],data=listings['city'],prefix='city'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['city'] = listings['city']
listings.drop(axis=1,labels='city',inplace=True)

# %%
dummy = pd.get_dummies(columns=listings['neighbourhood_group_cleansed'],data=listings['neighbourhood_group_cleansed']
                       ,prefix='neighbourhood_group_cleansed',prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['neighbourhood_group_cleansed'] = listings['neighbourhood_group_cleansed']
listings.drop(axis=1,labels='neighbourhood_group_cleansed',inplace=True)

# %%
dummy = pd.get_dummies(columns=listings['host_neighbourhood'],data=listings['host_neighbourhood'],prefix='host_neighbourhood'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['host_neighbourhood'] = listings['host_neighbourhood']
listings.drop(axis=1,labels='host_neighbourhood',inplace=True)

# %%
dummy = pd.get_dummies(columns=listings['host_response_time'],data=listings['host_response_time'],prefix='host_response_time'
                      ,prefix_sep='_')

listings = listings.merge(dummy,right_index=True,left_index=True)

listings_dummy['host_response_time'] = listings['host_response_time']
listings.drop(axis=1,labels='host_response_time',inplace=True)

# %% [markdown]
# Another way to dummify all above columns is to use Function - (Below is the Function but I haven't used it)

# %%
def create_dummy(column_name):
    
    '''
    USE OF FUNCTION : This function can be used to dummify the clumns in listings data

    INPUT:
    column_name(str) = Insert name of column you want to dummify

    OUTPUT:
    No return = All changes are made inside the function
    '''

    dummy = pd.get_dummies(columns=listings[column],data=listings[column_name],prefix=column_name
                      ,prefix_sep='_')

    listings = listings.merge(dummy,right_index=True,left_index=True)

    listings_dummy[column_name] = listings[column_name]
    listings.drop(axis=1,labels=column_name,inplace=True)

# %%
listings.columns[np.sum(listings.isna()) > 0]
# Out:
# Index([], dtype='object')

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59267 entries, 207 to 84848
# Columns: 191 entries, host_response_rate to host_response_time_within an hour
# dtypes: float64(19), int32(1), int64(29), uint8(142)
# memory usage: 32.9 MB

# %%
listings
# Out:
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 207                  98.0                 100.0                  1
# 208                  98.0                 100.0                  1
# 209                  98.0                 100.0                  1
# 210                  98.0                 100.0                  1
# 211                  98.0                 100.0                  1
# ...                   ...                   ...                ...
# 84771               100.0                 100.0                  0
# 84772               100.0                 100.0                  0
# 84846                99.0                 100.0                  0
# 84847               100.0                 100.0                  0
# 84848               100.0                 100.0                  0
#
#        host_listings_count  host_total_listings_count  host_has_profile_pic  \
# 207                    6.0                        6.0                     1
# 208                    6.0                        6.0                     1
# 209                    6.0                        6.0                     1
# 210                    6.0                        6.0                     1
# 211                    6.0                        6.0                     1
# ...                    ...                        ...                   ...
# 84771                  1.0                        1.0                     1
# 84772                  1.0                        1.0                     1
# 84846                354.0                      354.0                     1
# 84847                  1.0                        1.0                     1
# 84848                  1.0                        1.0                     1
#
#        host_identity_verified  zipcode  is_location_exact  accommodates  ...  \
# 207                         1    98119                  1             4  ...
# 208                         1    98119                  1             4  ...
# 209                         1    98119                  1             4  ...
# 210                         1    98119                  1             4  ...
# 211                         1    98119                  1             4  ...
# ...                       ...      ...                ...           ...  ...
# 84771                       1    98103                  1             3  ...
# 84772                       1    98103                  1             3  ...
# 84846                       1    98107                  1             6  ...
# 84847                       1    98102                  1             4  ...
# 84848                       1    98102                  1             4  ...
#
#        host_neighbourhood_Waianae Coast  host_neighbourhood_Wallingford  \
# 207                                   0                               0
# 208                                   0                               0
# 209                                   0                               0
# 210                                   0                               0
# 211                                   0                               0
# ...                                 ...                             ...
# 84771                                 0                               0
# 84772                                 0                               0
# 84846                                 0                               0
# 84847                                 0                               0
# 84848                                 0                               0
#
#        host_neighbourhood_Wedgewood  host_neighbourhood_Westlake  \
# 207                               0                            0
# 208                               0                            0
# 209                               0                            0
# 210                               0                            0
# 211                               0                            0
# ...                             ...                          ...
# 84771                             0                            0
# 84772                             0                            0
# 84846                             0                            0
# 84847                             0                            0
# 84848                             0                            0
#
#        host_neighbourhood_Windermere  host_neighbourhood_Yesler Terrace  \
# 207                                0                                  0
# 208                                0                                  0
# 209                                0                                  0
# 210                                0                                  0
# 211                                0                                  0
# ...                              ...                                ...
# 84771                              0                                  0
# 84772                              0                                  0
# 84846                              0                                  0
# 84847                              0                                  0
# 84848                              0                                  0
#
#        host_response_time_a few days or more  host_response_time_within a day  \
# 207                                        0                                0
# 208                                        0                                0
# 209                                        0                                0
# 210                                        0                                0
# 211                                        0                                0
# ...                                      ...                              ...
# 84771                                      0                                0
# 84772                                      0                                0
# 84846                                      0                                0
# 84847                                      0                                0
# 84848                                      0                                0
#
#        host_response_time_within a few hours  \
# 207                                        0
# 208                                        0
# 209                                        0
# 210                                        0
# 211                                        0
# ...                                      ...
# 84771                                      1
# 84772                                      1
# 84846                                      1
# 84847                                      0
# 84848                                      0
#
#        host_response_time_within an hour
# 207                                    1
# 208                                    1
# 209                                    1
# 210                                    1
# 211                                    1
# ...                                  ...
# 84771                                  0
# 84772                                  0
# 84846                                  0
# 84847                                  1
# 84848                                  1
#
# [59267 rows x 191 columns]

# %%
listings_dummy
# Out:
# 207                                                                     Apartment
# 208                                                                     Apartment
# 209                                                                     Apartment
# 210                                                                     Apartment
# 211                                                                     Apartment
#                                                       ...
# room_type                       207      Entire home/apt
# 208      Entire home/...
# city                            207      Seattle
# 208      Seattle
# 209      Sea...
# neighbourhood_group_cleansed    207               Queen Anne
# 208              ...
# host_neighbourhood              207       Queen Anne
# 208       Queen Anne
# 209 ...
# host_response_time              207          within an hour
# 208          withi...
# Name: property_type, Length: 59274, dtype: object

# %% [markdown]
# Now we split Prepared Data into Matrix of Features (X) and Dependent Variable Vector (y)

# %%
X = listings.loc[:, ~listings.columns.isin(['estimated_revenue'])].values
X
# Out:
# array([[ 98., 100.,   1., ...,   0.,   0.,   1.],
#        [ 98., 100.,   1., ...,   0.,   0.,   1.],
#        [ 98., 100.,   1., ...,   0.,   0.,   1.],
#        ...,
#        [ 99., 100.,   0., ...,   0.,   1.,   0.],
#        [100., 100.,   0., ...,   0.,   0.,   1.],
#        [100., 100.,   0., ...,   0.,   0.,   1.]])

# %%
y = listings.loc[:,'estimated_revenue'].values
y
# Out:
# array([ 300.,  300.,  300., ..., 1077.,  158.,  158.])

# %%
print(len(X))
print(len(y))
# Out:
# 59267
# 59267

# %%
from sklearn.decomposition import IncrementalPCA

pca = IncrementalPCA(n_components=10)

# %%
X_pca = pca.fit_transform(X)

# %%
len(X_pca)
# Out:
# 59267

# %%
X_pca
# Out:
# array([[-4.77627072e+02,  2.24362577e+01,  5.04207800e+01, ...,
#         -1.24434303e+01,  4.61290937e+00, -4.10006720e-01],
#        [-4.77627072e+02,  2.24362577e+01,  5.04207800e+01, ...,
#         -1.24434303e+01,  4.61290937e+00, -4.10006720e-01],
#        [-4.77626227e+02,  2.24345539e+01,  5.04071462e+01, ...,
#         -1.26353463e+01,  3.45161356e+00, -2.88120036e-01],
#        ...,
#        [ 5.57171613e+02, -2.46271010e+02,  2.83430077e+02, ...,
#          3.00736520e+01,  4.32579333e+01, -4.60305199e+00],
#        [-5.38296996e+02,  8.21387234e+00,  2.44313572e+01, ...,
#          1.18208478e+01, -1.69951848e+01,  6.12772700e-01],
#        [-5.38297043e+02,  8.21361756e+00,  2.44383354e+01, ...,
#          1.18832548e+01, -1.66136188e+01,  5.69003412e-01]])

# %%
len(X_pca[0])
# Out:
# 10

# %% [markdown]
# Splitting Dataset into Traing Set and Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_pca,y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (47413, 10)

# %% [markdown]
# Finally we Train the Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(normalize=True)

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9925257386764101

# %%
y_pred = regressor.predict(X_train)

# %%
r2_score(y_train,y_pred)
# Out:
# 0.9907726434363888

# %%
mean_absolute_error(y_train, y_pred)
# Out:
# 61.86347434278561

# %% [markdown]
# So Mean Absolute Error (Metric for Regession Model) is not so Big as compared to our Estimated Revenue Original Data therefore this Model is quite suitable for Prediction. r2_score is also confirming that the predictions are quite well

# %% [markdown]
# Therefore, Model can be used for in maing Predictions
